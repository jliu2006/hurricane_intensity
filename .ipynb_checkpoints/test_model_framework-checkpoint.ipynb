# %%
## importing all libraries for our models

# pandas
import pandas as pd

# tensorflow
import tensorflow as tf
from tensorflow import keras

# tensorflow.keras
from keras import Input
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten 
from keras.layers import Conv2D, Conv1D, MaxPooling2D
from keras.layers import AveragePooling2D, AveragePooling1D
from keras.layers import GlobalMaxPooling1D, GlobalAveragePooling2D
from keras.layers import BatchNormalization, LSTM
from keras.layers import Concatenate, concatenate 
# Concatenate returns Concatenate object (layers), concatenate returns Tensor object (arrays)
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from keras import backend as K
from keras.constraints import max_norm, non_neg, unit_norm, min_max_norm
#from tensorflow.keras.utils import plot_model


# numpy
import numpy as np
from numpy import random

# sklearn
import sklearn

# sklearn for pipeline mixins
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin

# sklearn for data splitting
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

# sklearn for models
from sklearn.svm import SVC  
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.model_selection import KFold
from sklearn.tree import export_graphviz
from sklearn.preprocessing import normalize

# sklearn for model evaluation
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score, roc_curve, auc, RocCurveDisplay
import sklearn.metrics.cluster as smc
from keras.layers.advanced_activations import LeakyReLU

# matplotlib.pyplot for plotting
from matplotlib import pyplot
import matplotlib.pyplot as plt 
import os

# misc
import itertools
from IPython.display import display
import matplotlib.pyplot as plt
import pydot
import graphviz
from PIL import Image
import numpy as np
from numpy import random
import glob
import rasterio as rio
import scipy.io as sio
import glob
import json

# %%
def get_max_wind(hurricane):
    name = hurricane + '/profile.json'
    f = open(name)
    profile = json.load(f)
    paths = profile['path']
    
    wind_speeds = []

    for path in paths:
        wind_speeds = np.append(wind_speeds, float(path['maxwind']))

    highest_wind = max(wind_speeds)
    
    print (hurricane, 'max wind ', get_max_wind)
    return highest_wind

def get_imerg(imerg):
    # get imerg
    precips = glob.glob(imerg, recursive = True)
    precips.sort()
    print (precips, " precips: ", temperatures)
    imerg_array = np.load(precips[0])
    
    for file in precips[1:10]:
        load = np.load(file)
        print(file, load.shape)
        imerg_array = np.append(imerg_array, load, axis = 0)
    imerg_array = imerg_array.reshape(1, 10, 200, 200)
    
    return imerg_array

def get_sst(sst):
    # get sst
    temperatures = glob.glob(sst, recursive = True)
    print (sst, " temperatures: ", temperatures)
    temperatures.sort()
    sst_array = np.load(temperatures[0])
    
    for file in temperatures[1:4]:
        sst_array = np.append(sst_array, np.load(file), axis = 0)
    sst_array = sst_array.reshape(1, 4, 200, 200)
    
    return sst_array

def get_rgb(rgb):
    # get wavelet decomposed rgb
    colors = glob.glob(rgb, recursive = True)
    print (colors, " rgbs: ", temperatures)
    colors.sort()
    rgb_array = np.load(colors[0])
    
    for file in colors[1:4]:
        rgb_array = np.append(rgb_array, np.load(file), axis = 0)
    
    rgb_array = rgb_array[:, :200, :200]
    rgb_array = rgb_array.reshape(1, 48, 200, 200)
    
    return rgb_array

def lenCheck(imerg, sst, rgb):
    imergs = glob.glob(imerg)
    ssts = glob.glob(sst)
    rgbs = glob.glob(rgb)
    
    if len(imergs) < 10 or len(ssts) < 4 or len(rgbs) < 4:
        return False
    else:
        return True
    
def landCheck(folder, imerg, sst, rgb):
    name = folder + '/profile.json'
    f = open(name)
    profile = json.load(f)
    paths = profile['path']

    valid_dates = []
    for path in paths:
        valid_dates = np.append(valid_dates, str(path['date']))
        
    file = folder + '/noaa_sst_*.npy'

    sst = glob.glob(file, recursive = True)
    sst.sort()
    sst = sst[0:4]
    
    valid = True

    days = []

    for imerg in imergs:
        days = np.append(days, sst[-17:-9])

    for day in days:
        if day not in valid_dates:
            valid = False
        else:
            valid = True

    return valid
    
def createWindMap(profile):
    # return nparray(1, 200, 200)
    # hurricane center is  at (99,99),   each direction expand by 100 miles
    
    res = np.zeros((200, 200))
    
    maxwindradius = min(int(float(profile['maxwindradius'])), 99)
    maxwind = float(profile['maxwind'])
    
    keys = []
    for it in profile.keys():
        if 'kt' in it:
            keys.append(it)        
    keys.sort()
    
    for it in keys:
        if "ne" in it:
            radius = min(int(float(profile[it])), 99)
            for i in range(0, radius):
                for j in range(0, radius):
                    res[100-i-1,  100 +j] = max(0, float(it[:-4]))
        elif "se" in it:
            radius = min(int(float(profile[it])), 99)
            for i in range(0, radius):
                for j in range(0, radius):
                    res[100 + i,  100 +j] = max(0, float(it[:-4]))
        elif "nw" in it:
            radius = min(int(float(profile[it])), 99)
            for i in range(0, radius):
                for j in range(0, radius):
                    res[100-i-1,  100-j-1] = max(0, float(it[:-4]))
        elif "sw" in it:
            radius = min(int(float(profile[it])), 99)
            for i in range(0, radius):
                for j in range(0, radius):
                    res[100 + i,  100-j-1] = max(0, float(it[:-4]))
                        
    for i in range(-maxwindradius, maxwindradius):
        for j in range(-maxwindradius, maxwindradius):
            res[99 + i, 99 + j] = maxwind
    
    res = np.expand_dims(res, axis = 0)
                    
    return res

# %%
def getCategory(wind_speed): # based on the Saffir-Simpson Scale for hurricane classification
    
    thresholds = [('TD', 33), ('TS', 63), ('Category_1', 82), ('Category_2', 95), ('Category_3', 112), ('Category_4', 136)]
    
    for it in thresholds:
        if wind_speed <= it[1]:
            return it[0]
    return thresholds[-1][0]

def selectDay(cat_dictionary):
    pick_days = []
    for key in cat_dictionary.keys():
        pick_days = np.append(pick_days, cat_dictionary[key][0])
    return pick_days

def getStageByDay(folder, day):
    
    imerg_names = folder + '/imerg_precipitation_' + day + '_*.npy'
    sst_names = folder + '/noaa_sst_' + day + '*.npy'
    rgb_names = folder + '/10_wavelet_rgb_' + day + '*.npy'
    #rgb_names = folder + '/10_modis_satellite_' + day + '*.npy'
    
    profile_name = folder + '/profile.json'
    f = open(profile_name)
    profile = json.load(f)
    paths = profile['path']

    imergs = glob.glob(imerg_names, recursive = True)
    ssts = glob.glob(sst_names, recursive = True)
    rgbs = glob.glob(rgb_names, recursive = True)
    
    imerg_array = np.zeros((200, 200))
    for imerg in imergs:
        im_arr = np.load(imerg)
        print(imerg, len(im_arr.flatten()))
        if not (sizeCheck(im_arr)):
            continue
        imerg_array = imerg_array + np.load(imerg)

    imerg_array = imerg_array.reshape(1, 200, 200)
    imerg_array = imerg_array / len(imergs)
    
    if (not rgbs) or (not ssts):
        #print("no rgbs or ssts: ", folder, day)
        return None
    
    
    sst_array = np.load(ssts[0])
    print(sst_array.shape, folder)
    
    if (not sizeCheck(sst_array)) or (not sizeCheck(imerg_array)):      
        #print("sst shape invalid: ", folder, day)
        return None

    rgb_array = np.load(rgbs[0])
    
    #rgb_array = rgb_array[100:300, 100:300, :]
    print(rgb_array.shape)
        
        
    selected_days = []

    for path in paths:
        if path['date'] == int(day):
            selected_days.append(path)
        
    # pick mid element from path    
    middleIndex = int((len(selected_days) - 1)/2)
    if len(selected_days) == 2: 
        middleIndex = 1
        
    selected_day = selected_days[middleIndex]

    wind_array = createWindMap(selected_day)
    
    #stage_array = imerg_array
    #stage_array = np.append(stage_array, sst_array, axis = 0)
    
    stage_array = rgb_array
    
    #stage_array = np.append(stage_array, rgb_array, axis = 0)
    #stage_array = np.append(stage_array, wind_array, axis = 0)
    stage_array = np.expand_dims(stage_array, axis = 0)
    
    return stage_array

def sizeCheck(tensor): # size check should happen after stage data is collected
    shape = len(tensor.flatten())
    print(shape)
    if shape != 40000:
        return False
    else:
        return True
    
def populateStage(stage, step):
    if step is None:
        return stage
    if stage is None:
        stage = step
    else:
        stage = np.append(stage, step, axis = 0)
    return stage

# %%
# outdated data collection methodology -- moved on as of 11/08/2022
def OUTDATED_DATA_COLLECTION():
    highest_wind = np.empty([0])
    imerg_precip = np.empty([1, 10, 200, 200])
    skin_temp = np.empty([1, 4, 200, 200])
    dwt_rgb = np.empty([1, 48, 200, 200])

    all_folders = glob.glob('/home/fun/data/AL*20*')
    all_folders.sort()

    len_fail = 0
    land_fail = 0

    for folder in all_folders:
        imerg_names = folder + '/imerg_precipitation_*.npy'
        sst_names = folder + '/noaa_sst_*.npy'
        rgb_names = folder + '/wavelet_rgb_*.npy'

        if not lenCheck(imerg_names, sst_names, rgb_names):
            print("skipping lenCheck ", folder)
            len_fail += 1
            continue
        if not landCheck(folder, imerg_names, sst_names, rgb_names):
            print("skipping landCheck ", folder)
            land_fail += 1
            continue

        imerg_precip = np.append(imerg_precip, get_imerg(imerg_names), axis = 0) # X data (train class)
        skin_temp = np.append(skin_temp, get_sst(sst_names), axis = 0) # X data (train class)
        dwt_rgb = np.append(dwt_rgb, get_rgb(rgb_names), axis = 0)

        highest_wind = np.append(highest_wind, get_max_wind(folder)) # Y data (target class)

    imerg_precip = imerg_precip[1:]
    skin_temp = skin_temp[1:]
    dwt_rgb = dwt_rgb[1:]

    print(imerg_precip.shape, skin_temp.shape, dwt_rgb.shape, highest_wind.shape)
    print("len_fail: ", len_fail)
    print("land_fail: ", land_fail)
    
    return None # OUTDATED DATA COLLECTION METHOD AS OF 11/08/2022

# %%
def completeDataCollection(globname, max_wind_param): # NEW DATA COLLECTION METHOD - SORT INTO STAGES

    folders = glob.glob(globname, recursive = True)
    # AL032000, failed rgb glob (no modis satellite data for that day)
    # AL242005, failed ssts glob (no sst satellite data for that day)
    stage_1 = None
    stage_2 = None
    stage_3 = None
    highest_wind = None

    for folder in folders:
        print(type(stage_1))
        name = folder + '/profile.json'
        f = open(name)
        prof = json.load(f)
        paths = prof['path']

        cats = {} # dictionary with categories as keys, days as values.
        # used to extract day values based on hurricane category (stage)

        for path in paths:
            if int(path['maxwind']) < int(max_wind_param): # only select hurricanes with wind speed at least max_wind_param
                continue
            test = getCategory(int(path['maxwind']))

            if test not in cats.keys():
                cats[test] = []
            cats[test].append(str(path['date']))

        for key in cats.keys():
            cats[key] = list(set(cats[key]))
            cats[key].sort()

        days = selectDay(cats)
        print("category ", cats)
        print ("days:", days)
        if len(days) < 3:
            #print("not enough categories: ", folder)
            continue

        #print("valid folder: ", folder)


        step_1 = getStageByDay(folder, days[0])
        step_2 = getStageByDay(folder, days[1])
        step_3 = getStageByDay(folder, days[2])


        if (step_1 is None) or (step_2 is None) or (step_3 is None):
            #print("size not fit: ", folder)
            continue

        highest_wind = np.append(highest_wind, get_max_wind(folder))
        
        stage_1 = populateStage(stage_1, step_1)
        stage_2 = populateStage(stage_2, step_2)
        stage_3 = populateStage(stage_3, step_3)
        
        print("APPENDED", folder, " highest_wind", highest_wind)

        

    highest_wind = highest_wind[1:]
    print(stage_1.shape, stage_2.shape, stage_3.shape, highest_wind.shape)
    
    return stage_1, stage_2, stage_3, highest_wind

# %%
stage_1, stage_2, stage_3, highest_wind = completeDataCollection('/home/fun/data/AL*20*', 0)
# Out:
# <class 'NoneType'>
# category  {'TD': ['20040803', '20040804', '20040805', '20040806', '20040807', '20040808', '20040809'], 'TS': ['20040809', '20040810', '20040811', '20040812']}
# days: ['20040803' '20040809']
# <class 'NoneType'>
# category  {'TD': ['20040813', '20040820', '20040821', '20040822', '20040823', '20040824'], 'TS': ['20040814', '20040818', '20040819', '20040820'], 'Category_1': ['20040815', '20040818'], 'Category_2': ['20040815', '20040816', '20040817']}
# days: ['20040813' '20040814' '20040815' '20040815']
# /home/fun/data/AL042004/imerg_precipitation_20040813_1200.npy 40000
# 40000
# /home/fun/data/AL042004/imerg_precipitation_20040813_1800.npy 40000
# 40000
# (1, 200, 192) /home/fun/data/AL042004
# 38400
# /home/fun/data/AL042004/imerg_precipitation_20040814_0000.npy 40000
# 40000
# /home/fun/data/AL042004/imerg_precipitation_20040814_0600.npy 40000
# 40000
# /home/fun/data/AL042004/imerg_precipitation_20040814_1200.npy 40000
# 40000
# /home/fun/data/AL042004/imerg_precipitation_20040814_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL042004
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL042004/imerg_precipitation_20040815_0000.npy 40000
# 40000
# /home/fun/data/AL042004/imerg_precipitation_20040815_0600.npy 40000
# 40000
# /home/fun/data/AL042004/imerg_precipitation_20040815_1200.npy 40000
# 40000
# /home/fun/data/AL042004/imerg_precipitation_20040815_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL042004
# 40000
# 40000
# (200, 200, 3)
# <class 'NoneType'>
# category  {'TD': ['20040813', '20040814'], 'TS': ['20040814', '20040815']}
# days: ['20040813' '20040814']
# <class 'NoneType'>
# category  {'TD': ['20040827', '20040828'], 'TS': ['20040828', '20040829'], 'Category_1': ['20040829']}
# days: ['20040827' '20040828' '20040829']
# /home/fun/data/AL072004/imerg_precipitation_20040827_1200.npy 40000
# 40000
# /home/fun/data/AL072004/imerg_precipitation_20040827_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL072004
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL072004/imerg_precipitation_20040828_0000.npy 40000
# 40000
# /home/fun/data/AL072004/imerg_precipitation_20040828_0600.npy 40000
# 40000
# /home/fun/data/AL072004/imerg_precipitation_20040828_1200.npy 40000
# 40000
# /home/fun/data/AL072004/imerg_precipitation_20040828_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL072004
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL072004/imerg_precipitation_20040829_0000.npy 40000
# 40000
# /home/fun/data/AL072004/imerg_precipitation_20040829_0600.npy 40000
# 40000
# /home/fun/data/AL072004/imerg_precipitation_20040829_1200.npy 40000
# 40000
# /home/fun/data/AL072004/imerg_precipitation_20040829_1400.npy 10000
# 10000
# /home/fun/data/AL072004/imerg_precipitation_20040829_1800.npy 10000
# 10000
# (1, 200, 200) /home/fun/data/AL072004
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL072004 max wind  <function get_max_wind at 0x7fe150a89378>
# APPENDED /home/fun/data/AL072004  highest_wind [None 65.0]
# <class 'numpy.ndarray'>
# category  {'TD': ['20040827', '20040828', '20040829'], 'TS': ['20040829', '20040830', '20040831']}
# days: ['20040827' '20040829']
# <class 'numpy.ndarray'>
# category  {'TD': ['20040907', '20040908', '20040909', '20040910']}
# days: ['20040907']
# <class 'numpy.ndarray'>
# category  {'TD': ['20040913', '20040914']}
# days: ['20040913']
# <class 'numpy.ndarray'>
# category  {'TD': ['20060903', '20060904', '20060905'], 'TS': ['20060905', '20060906', '20060907', '20060908', '20060909', '20060910', '20060914', '20060915', '20060916', '20060917', '20060918', '20060919'], 'Category_1': ['20060910', '20060911', '20060912', '20060913', '20060914']}
# days: ['20060903' '20060905' '20060910']
# /home/fun/data/AL072006/imerg_precipitation_20060903_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL072006
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL072006/imerg_precipitation_20060905_0000.npy 40000
# 40000
# /home/fun/data/AL072006/imerg_precipitation_20060905_0600.npy 40000
# 40000
# /home/fun/data/AL072006/imerg_precipitation_20060905_1200.npy 40000
# 40000
# /home/fun/data/AL072006/imerg_precipitation_20060905_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL072006
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL072006/imerg_precipitation_20060910_1800.npy 40000
# 40000
# /home/fun/data/AL072006/imerg_precipitation_20060910_0000.npy 40000
# 40000
# /home/fun/data/AL072006/imerg_precipitation_20060910_0600.npy 40000
# 40000
# /home/fun/data/AL072006/imerg_precipitation_20060910_1200.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL072006
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL072006 max wind  <function get_max_wind at 0x7fe150a89378>
# APPENDED /home/fun/data/AL072006  highest_wind [None 65.0 80.0]
# <class 'numpy.ndarray'>
# category  {'TD': ['20000607', '20000608']}
# days: ['20000607']
# <class 'numpy.ndarray'>
# category  {'TD': ['20000623', '20000624', '20000625']}
# days: ['20000623']
# <class 'numpy.ndarray'>
# category  {'TD': ['20000803', '20000804', '20000824', '20000825'], 'TS': ['20000804', '20000805', '20000809', '20000814', '20000815', '20000816', '20000817', '20000818', '20000823', '20000824'], 'Category_1': ['20000806', '20000807', '20000808', '20000810', '20000811', '20000813', '20000814', '20000818', '20000819', '20000821', '20000822', '20000823'], 'Category_2': ['20000811', '20000812', '20000813', '20000819', '20000820', '20000821'], 'Category_3': ['20000812', '20000813']}
# days: ['20000803' '20000804' '20000806' '20000811' '20000812']
# /home/fun/data/AL032000/imerg_precipitation_20000803_1800.npy 40000
# 40000
# (1, 200, 172) /home/fun/data/AL032000
# 34400
# /home/fun/data/AL032000/imerg_precipitation_20000804_0000.npy 40000
# 40000
# /home/fun/data/AL032000/imerg_precipitation_20000804_0600.npy 40000
# 40000
# /home/fun/data/AL032000/imerg_precipitation_20000804_1200.npy 40000
# 40000
# /home/fun/data/AL032000/imerg_precipitation_20000804_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL032000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL032000/imerg_precipitation_20000806_0000.npy 40000
# 40000
# /home/fun/data/AL032000/imerg_precipitation_20000806_0600.npy 40000
# 40000
# /home/fun/data/AL032000/imerg_precipitation_20000806_1200.npy 40000
# 40000
# /home/fun/data/AL032000/imerg_precipitation_20000806_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL032000
# 40000
# 40000
# (200, 200, 3)
# <class 'numpy.ndarray'>
# category  {'TD': ['20000808', '20000809', '20000810', '20000811']}
# days: ['20000808']
# <class 'numpy.ndarray'>
# category  {'TD': ['20000813', '20000814', '20000815'], 'TS': ['20000814', '20000815']}
# days: ['20000813' '20000814']
# <class 'numpy.ndarray'>
# category  {'TD': ['20000817', '20000818', '20000819'], 'TS': ['20000818']}
# days: ['20000817' '20000818']
# <class 'numpy.ndarray'>
# category  {'TD': ['20000819', '20000820'], 'TS': ['20000820', '20000821'], 'Category_1': ['20000821', '20000822']}
# days: ['20000819' '20000820' '20000821']
# /home/fun/data/AL072000/imerg_precipitation_20000819_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL072000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL072000/imerg_precipitation_20000820_0000.npy 40000
# 40000
# /home/fun/data/AL072000/imerg_precipitation_20000820_0600.npy 40000
# 40000
# /home/fun/data/AL072000/imerg_precipitation_20000820_1200.npy 40000
# 40000
# /home/fun/data/AL072000/imerg_precipitation_20000820_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL072000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL072000/imerg_precipitation_20000821_0000.npy 40000
# 40000
# /home/fun/data/AL072000/imerg_precipitation_20000821_0600.npy 40000
# 40000
# /home/fun/data/AL072000/imerg_precipitation_20000821_1200.npy 40000
# 40000
# /home/fun/data/AL072000/imerg_precipitation_20000821_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL072000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL072000 max wind  <function get_max_wind at 0x7fe150a89378>
# APPENDED /home/fun/data/AL072000  highest_wind [None 65.0 80.0 75.0]
# <class 'numpy.ndarray'>
# category  {'TD': ['20000901', '20000902', '20000903'], 'TS': ['20000902', '20000903']}
# days: ['20000901' '20000902']
# <class 'numpy.ndarray'>
# category  {'TD': ['20000908', '20000909']}
# days: ['20000908']
# <class 'numpy.ndarray'>
# category  {'TD': ['20000910', '20000911'], 'TS': ['20000911', '20000912', '20000913', '20000914', '20000915', '20000917'], 'Category_1': ['20000911', '20000912', '20000913', '20000916']}
# days: ['20000910' '20000911' '20000911']
# /home/fun/data/AL102000/imerg_precipitation_20000910_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL102000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL102000/imerg_precipitation_20000911_0000.npy 40000
# 40000
# /home/fun/data/AL102000/imerg_precipitation_20000911_0600.npy 40000
# 40000
# /home/fun/data/AL102000/imerg_precipitation_20000911_1200.npy 40000
# 40000
# /home/fun/data/AL102000/imerg_precipitation_20000911_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL102000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL102000/imerg_precipitation_20000911_0000.npy 40000
# 40000
# /home/fun/data/AL102000/imerg_precipitation_20000911_0600.npy 40000
# 40000
# /home/fun/data/AL102000/imerg_precipitation_20000911_1200.npy 40000
# 40000
# /home/fun/data/AL102000/imerg_precipitation_20000911_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL102000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL102000 max wind  <function get_max_wind at 0x7fe150a89378>
# APPENDED /home/fun/data/AL102000  highest_wind [None 65.0 80.0 75.0 70.0]
# <class 'numpy.ndarray'>
# category  {'TD': ['20000914', '20000915'], 'TS': ['20000916', '20000918'], 'Category_1': ['20000917']}
# days: ['20000914' '20000916' '20000917']
# /home/fun/data/AL112000/imerg_precipitation_20000914_1200.npy 40000
# 40000
# /home/fun/data/AL112000/imerg_precipitation_20000914_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL112000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL112000/imerg_precipitation_20000916_0000.npy 40000
# 40000
# /home/fun/data/AL112000/imerg_precipitation_20000916_0600.npy 40000
# 40000
# /home/fun/data/AL112000/imerg_precipitation_20000916_1200.npy 40000
# 40000
# /home/fun/data/AL112000/imerg_precipitation_20000916_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL112000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL112000/imerg_precipitation_20000917_0000.npy 40000
# 40000
# /home/fun/data/AL112000/imerg_precipitation_20000917_0600.npy 40000
# 40000
# /home/fun/data/AL112000/imerg_precipitation_20000917_1200.npy 40000
# 40000
# /home/fun/data/AL112000/imerg_precipitation_20000917_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL112000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL112000 max wind  <function get_max_wind at 0x7fe150a89378>
# APPENDED /home/fun/data/AL112000  highest_wind [None 65.0 80.0 75.0 70.0 70.0]
# <class 'numpy.ndarray'>
# category  {'TD': ['20000915', '20000916', '20000917', '20000918', '20000919', '20000920', '20000921'], 'TS': ['20000921', '20000922']}
# days: ['20000915' '20000921']
# <class 'numpy.ndarray'>
# category  {'TD': ['20000921'], 'TS': ['20000922', '20000923', '20001001', '20001002', '20001003', '20001004'], 'Category_1': ['20000923', '20000926', '20000927', '20000930', '20001001'], 'Category_2': ['20000923', '20000925', '20000926', '20000927', '20000929', '20000930'], 'Category_3': ['20000924', '20000928', '20000929'], 'Category_4': ['20000928', '20000929']}
# days: ['20000921' '20000922' '20000923' '20000923' '20000924' '20000928']
# /home/fun/data/AL132000/imerg_precipitation_20000921_1200.npy 40000
# 40000
# /home/fun/data/AL132000/imerg_precipitation_20000921_1800.npy 40000
# 40000
# (1, 200, 198) /home/fun/data/AL132000
# 39600
# /home/fun/data/AL132000/imerg_precipitation_20000922_0000.npy 40000
# 40000
# /home/fun/data/AL132000/imerg_precipitation_20000922_0600.npy 40000
# 40000
# /home/fun/data/AL132000/imerg_precipitation_20000922_1200.npy 40000
# 40000
# /home/fun/data/AL132000/imerg_precipitation_20000922_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL132000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL132000/imerg_precipitation_20000923_0000.npy 40000
# 40000
# /home/fun/data/AL132000/imerg_precipitation_20000923_0600.npy 40000
# 40000
# /home/fun/data/AL132000/imerg_precipitation_20000923_1200.npy 40000
# 40000
# /home/fun/data/AL132000/imerg_precipitation_20000923_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL132000
# 40000
# 40000
# (200, 200, 3)
# <class 'numpy.ndarray'>
# category  {'TD': ['20000925', '20001001', '20001002'], 'TS': ['20000926', '20000927', '20000929', '20000930', '20001001'], 'Category_1': ['20000927', '20000928', '20000929']}
# days: ['20000925' '20000926' '20000927']
# /home/fun/data/AL142000/imerg_precipitation_20000925_1200.npy 40000
# 40000
# /home/fun/data/AL142000/imerg_precipitation_20000925_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL142000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL142000/imerg_precipitation_20000926_0000.npy 40000
# 40000
# /home/fun/data/AL142000/imerg_precipitation_20000926_0600.npy 40000
# 40000
# /home/fun/data/AL142000/imerg_precipitation_20000926_1200.npy 40000
# 40000
# /home/fun/data/AL142000/imerg_precipitation_20000926_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL142000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL142000/imerg_precipitation_20000927_0000.npy 40000
# 40000
# /home/fun/data/AL142000/imerg_precipitation_20000927_0600.npy 40000
# 40000
# /home/fun/data/AL142000/imerg_precipitation_20000927_1200.npy 40000
# 40000
# /home/fun/data/AL142000/imerg_precipitation_20000927_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL142000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL142000 max wind  <function get_max_wind at 0x7fe150a89378>
# APPENDED /home/fun/data/AL142000  highest_wind [None 65.0 80.0 75.0 70.0 70.0 80.0]
# <class 'numpy.ndarray'>
# category  {'TD': ['20000928', '20000929'], 'TS': ['20000929', '20000930'], 'Category_1': ['20000930', '20001002'], 'Category_3': ['20001001', '20001002'], 'Category_4': ['20001001']}
# days: ['20000928' '20000929' '20000930' '20001001' '20001001']
# /home/fun/data/AL152000/imerg_precipitation_20000928_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL152000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL152000/imerg_precipitation_20000929_0000.npy 40000
# 40000
# /home/fun/data/AL152000/imerg_precipitation_20000929_0600.npy 40000
# 40000
# /home/fun/data/AL152000/imerg_precipitation_20000929_1200.npy 40000
# 40000
# /home/fun/data/AL152000/imerg_precipitation_20000929_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL152000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL152000/imerg_precipitation_20000930_0000.npy 40000
# 40000
# /home/fun/data/AL152000/imerg_precipitation_20000930_0600.npy 40000
# 40000
# /home/fun/data/AL152000/imerg_precipitation_20000930_1200.npy 40000
# 40000
# /home/fun/data/AL152000/imerg_precipitation_20000930_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL152000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL152000 max wind  <function get_max_wind at 0x7fe150a89378>
# APPENDED /home/fun/data/AL152000  highest_wind [None 65.0 80.0 75.0 70.0 70.0 80.0 120.0]
# <class 'numpy.ndarray'>
# category  {'TD': ['20001004', '20001005'], 'TS': ['20001005', '20001006', '20001007', '20001008', '20001009', '20001010']}
# days: ['20001004' '20001005']
# <class 'numpy.ndarray'>
# category  {'TD': ['20001015'], 'TS': ['20001016', '20001017', '20001020'], 'Category_1': ['20001017', '20001018', '20001019', '20001020'], 'Category_2': ['20001019']}
# days: ['20001015' '20001016' '20001017' '20001019']
# /home/fun/data/AL172000/imerg_precipitation_20001015_1200.npy 40000
# 40000
# /home/fun/data/AL172000/imerg_precipitation_20001015_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL172000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL172000/imerg_precipitation_20001016_0000.npy 40000
# 40000
# /home/fun/data/AL172000/imerg_precipitation_20001016_0600.npy 40000
# 40000
# /home/fun/data/AL172000/imerg_precipitation_20001016_1200.npy 40000
# 40000
# /home/fun/data/AL172000/imerg_precipitation_20001016_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL172000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL172000/imerg_precipitation_20001017_0000.npy 40000
# 40000
# /home/fun/data/AL172000/imerg_precipitation_20001017_0600.npy 40000
# 40000
# /home/fun/data/AL172000/imerg_precipitation_20001017_1200.npy 40000
# 40000
# /home/fun/data/AL172000/imerg_precipitation_20001017_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL172000
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL172000 max wind  <function get_max_wind at 0x7fe150a89378>
# APPENDED /home/fun/data/AL172000  highest_wind [None 65.0 80.0 75.0 70.0 70.0 80.0 120.0 85.0]
# <class 'numpy.ndarray'>
# category  {'TD': ['20001019', '20001020'], 'TS': ['20001020', '20001021', '20001022']}
# days: ['20001019' '20001020']
# <class 'numpy.ndarray'>
# category  {'TD': ['20001025'], 'TS': ['20001025', '20001026', '20001027', '20001028', '20001029']}
# days: ['20001025' '20001025']
# <class 'numpy.ndarray'>
# category  {'TS': ['20010605']}
# days: ['20010605']
# <class 'numpy.ndarray'>
# category  {'TD': ['20010711', '20010712']}
# days: ['20010711']
# <class 'numpy.ndarray'>
# category  {'TD': ['20010802', '20010804'], 'TS': ['20010802', '20010803', '20010804', '20010805', '20010806']}
# days: ['20010802' '20010802']
# <class 'numpy.ndarray'>
# category  {'TD': ['20010814', '20010815', '20010816'], 'TS': ['20010817', '20010818', '20010819', '20010820', '20010821']}
# days: ['20010814' '20010817']
# <class 'numpy.ndarray'>
# category  {'TS': ['20010822', '20010823', '20010827', '20010828', '20010829'], 'TD': ['20010823', '20010824', '20010825', '20010826']}
# days: ['20010822' '20010823']
# <class 'numpy.ndarray'>
# category  {'TD': ['20010901', '20010902', '20010905', '20010906', '20010907'], 'TS': ['20010902', '20010903', '20010904', '20010905', '20010907', '20010908', '20010915', '20010916', '20010917'], 'Category_1': ['20010909', '20010911', '20010912', '20010913', '20010914'], 'Category_2': ['20010909', '20010910'], 'Category_3': ['20010909', '20010910']}
# days: ['20010901' '20010902' '20010909' '20010909' '20010909']
# /home/fun/data/AL062001/imerg_precipitation_20010901_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/A
# 40000
# /home/fun/data/AL292020/imerg_precipitation_20201102_1800.npy 40000
# 40000
# <class 'numpy.ndarray'>
# category  {'TD': ['20201108', '20201109', '20201115', '20201116'], 'TS': ['20201109', '20201110', '20201111', '20201112', '20201113', '20201114', '20201115']}
# days: ['20201108' '20201109']
# <class 'numpy.ndarray'>
# category  {'TD': ['20201112', '20201113'], 'TS': ['20201113', '20201114', '20201115'], 'Category_1': ['20201115'], 'Category_2': ['20201116'], 'Category_4': ['20201116', '20201117']}
# days: ['20201112' '20201113' '20201115' '20201116' '20201116']
# /home/fun/data/AL312020/imerg_precipitation_20201112_1200.npy 40000
# 40000
# /home/fun/data/AL312020/imerg_precipitation_20201112_1800.npy 40000
# 40000
# /home/fun/data/AL312020/imerg_precipitation_20201113_0000.npy 40000
# 40000
# /home/fun/data/AL312020/imerg_precipitation_20201113_0600.npy 40000
# 40000
# /home/fun/data/AL312020/imerg_precipitation_20201113_1200.npy 40000
# 40000
# /home/fun/data/AL312020/imerg_precipitation_20201113_1800.npy 40000
# 40000
# /home/fun/data/AL312020/imerg_precipitation_20201115_0000.npy 40000
# 40000
# /home/fun/data/AL312020/imerg_precipitation_20201115_0600.npy 40000
# 40000
# /home/fun/data/AL312020/imerg_precipitation_20201115_1200.npy 40000
# 40000
# /home/fun/data/AL312020/imerg_precipitation_20201115_1800.npy 40000
# 40000
# <class 'numpy.ndarray'>
# category  {'TD': ['20210520'], 'TS': ['20210520', '20210521', '20210522', '20210523', '20210524']}
# days: ['20210520' '20210520']
# <class 'numpy.ndarray'>
# category  {'TD': ['20210613', '20210614'], 'TS': ['20210614', '20210615', '20210616']}
# days: ['20210613' '20210614']
# <class 'numpy.ndarray'>
# category  {'TD': ['20210617', '20210618'], 'TS': ['20210618', '20210619']}
# days: ['20210617' '20210618']
# <class 'numpy.ndarray'>
# category  {'TD': ['20210627', '20210628'], 'TS': ['20210628']}
# days: ['20210627' '20210628']
# <class 'numpy.ndarray'>
# category  {'TD': ['20210630'], 'TS': ['20210701', '20210702', '20210703', '20210704', '20210705', '20210706', '20210707'], 'Category_1': ['20210702', '20210703', '20210707']}
# days: ['20210630' '20210701' '20210702']
# /home/fun/data/AL052021/imerg_precipitation_20210630_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL052021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL052021/imerg_precipitation_20210701_0000.npy 40000
# 40000
# /home/fun/data/AL052021/imerg_precipitation_20210701_0600.npy 40000
# 40000
# /home/fun/data/AL052021/imerg_precipitation_20210701_1200.npy 40000
# 40000
# /home/fun/data/AL052021/imerg_precipitation_20210701_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL052021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL052021/imerg_precipitation_20210702_0000.npy 40000
# 40000
# /home/fun/data/AL052021/imerg_precipitation_20210702_0600.npy 40000
# 40000
# /home/fun/data/AL052021/imerg_precipitation_20210702_1200.npy 40000
# 40000
# /home/fun/data/AL052021/imerg_precipitation_20210702_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL052021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL052021 max wind  <function get_max_wind at 0x7fe150a89378>
# APPENDED /home/fun/data/AL052021  highest_wind [None 65.0 80.0 75.0 70.0 70.0 80.0 120.0 85.0 105.0 100.0 90.0 125.0 70.0
#  120.0 80.0 85.0 110.0 75.0 125.0 70.0 65.0 125.0 145.0 90.0 110.0 105.0
#  125.0 125.0 145.0 125.0 65.0 75.0 90.0 100.0 80.0 70.0 155.0 160.0 100.0
#  65.0 105.0 75.0 65.0 150.0 80.0 65.0 70.0 75.0 110.0 135.0 75.0 125.0
#  75.0 115.0 125.0 115.0 65.0 115.0 75.0 75.0 85.0 65.0 70.0 65.0 120.0
#  100.0 75.0 80.0 95.0 70.0 90.0 70.0 100.0 80.0 100.0 75.0 85.0 70.0 75.0
#  105.0 65.0 110.0 135.0 75.0 70.0 145.0 120.0 100.0 95.0 155.0 135.0 90.0
#  70.0 90.0 65.0 65.0 110.0 90.0 80.0 65.0 80.0 75.0]
# <class 'numpy.ndarray'>
# category  {'TD': ['20210809', '20210810', '20210812', '20210813', '20210814'], 'TS': ['20210811', '20210813', '20210815', '20210816']}
# days: ['20210809' '20210811']
# <class 'numpy.ndarray'>
# category  {'TD': ['20210813', '20210814', '20210815', '20210816'], 'TS': ['20210814', '20210816', '20210817', '20210818'], 'Category_1': ['20210818', '20210819']}
# days: ['20210813' '20210814' '20210818']
# /home/fun/data/AL072021/imerg_precipitation_20210813_0600.npy 40000
# 40000
# /home/fun/data/AL072021/imerg_precipitation_20210813_1200.npy 40000
# 40000
# /home/fun/data/AL072021/imerg_precipitation_20210813_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL072021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL072021/imerg_precipitation_20210814_0000.npy 40000
# 40000
# /home/fun/data/AL072021/imerg_precipitation_20210814_0600.npy 40000
# 40000
# /home/fun/data/AL072021/imerg_precipitation_20210814_1200.npy 40000
# 40000
# /home/fun/data/AL072021/imerg_precipitation_20210814_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL072021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL072021/imerg_precipitation_20210818_0000.npy 40000
# 40000
# /home/fun/data/AL072021/imerg_precipitation_20210818_0600.npy 40000
# 40000
# /home/fun/data/AL072021/imerg_precipitation_20210818_1200.npy 40000
# 40000
# /home/fun/data/AL072021/imerg_precipitation_20210818_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL072021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL072021 max wind  <function get_max_wind at 0x7fe150a89378>
# APPENDED /home/fun/data/AL072021  highest_wind [None 65.0 80.0 75.0 70.0 70.0 80.0 120.0 85.0 105.0 100.0 90.0 125.0 70.0
#  120.0 80.0 85.0 110.0 75.0 125.0 70.0 65.0 125.0 145.0 90.0 110.0 105.0
#  125.0 125.0 145.0 125.0 65.0 75.0 90.0 100.0 80.0 70.0 155.0 160.0 100.0
#  65.0 105.0 75.0 65.0 150.0 80.0 65.0 70.0 75.0 110.0 135.0 75.0 125.0
#  75.0 115.0 125.0 115.0 65.0 115.0 75.0 75.0 85.0 65.0 70.0 65.0 120.0
#  100.0 75.0 80.0 95.0 70.0 90.0 70.0 100.0 80.0 100.0 75.0 85.0 70.0 75.0
#  105.0 65.0 110.0 135.0 75.0 70.0 145.0 120.0 100.0 95.0 155.0 135.0 90.0
#  70.0 90.0 65.0 65.0 110.0 90.0 80.0 65.0 80.0 75.0 70.0]
# <class 'numpy.ndarray'>
# category  {'TD': ['20210815', '20210816'], 'TS': ['20210816', '20210817', '20210818', '20210819', '20210820', '20210821', '20210822'], 'Category_1': ['20210821', '20210822']}
# days: ['20210815' '20210816' '20210821']
# /home/fun/data/AL082021/imerg_precipitation_20210815_0000.npy 40000
# 40000
# /home/fun/data/AL082021/imerg_precipitation_20210815_0600.npy 40000
# 40000
# /home/fun/data/AL082021/imerg_precipitation_20210815_1200.npy 40000
# 40000
# /home/fun/data/AL082021/imerg_precipitation_20210815_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL082021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL082021/imerg_precipitation_20210816_0000.npy 40000
# 40000
# /home/fun/data/AL082021/imerg_precipitation_20210816_0600.npy 40000
# 40000
# /home/fun/data/AL082021/imerg_precipitation_20210816_1200.npy 40000
# 40000
# /home/fun/data/AL082021/imerg_precipitation_20210816_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL082021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL082021/imerg_precipitation_20210821_0000.npy 40000
# 40000
# /home/fun/data/AL082021/imerg_precipitation_20210821_0600.npy 40000
# 40000
# /home/fun/data/AL082021/imerg_precipitation_20210821_1200.npy 40000
# 40000
# /home/fun/data/AL082021/imerg_precipitation_20210821_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL082021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL082021 max wind  <function get_max_wind at 0x7fe150a89378>
# APPENDED /home/fun/data/AL082021  highest_wind [None 65.0 80.0 75.0 70.0 70.0 80.0 120.0 85.0 105.0 100.0 90.0 125.0 70.0
#  120.0 80.0 85.0 110.0 75.0 125.0 70.0 65.0 125.0 145.0 90.0 110.0 105.0
#  125.0 125.0 145.0 125.0 65.0 75.0 90.0 100.0 80.0 70.0 155.0 160.0 100.0
#  65.0 105.0 75.0 65.0 150.0 80.0 65.0 70.0 75.0 110.0 135.0 75.0 125.0
#  75.0 115.0 125.0 115.0 65.0 115.0 75.0 75.0 85.0 65.0 70.0 65.0 120.0
#  100.0 75.0 80.0 95.0 70.0 90.0 70.0 100.0 80.0 100.0 75.0 85.0 70.0 75.0
#  105.0 65.0 110.0 135.0 75.0 70.0 145.0 120.0 100.0 95.0 155.0 135.0 90.0
#  70.0 90.0 65.0 65.0 110.0 90.0 80.0 65.0 80.0 75.0 70.0 65.0]
# <class 'numpy.ndarray'>
# category  {'TD': ['20210826'], 'TS': ['20210826', '20210827'], 'Category_1': ['20210827', '20210828'], 'Category_2': ['20210829'], 'Category_4': ['20210829']}
# days: ['20210826' '20210826' '20210827' '20210829' '20210829']
# /home/fun/data/AL092021/imerg_precipitation_20210826_1200.npy 40000
# 40000
# /home/fun/data/AL092021/imerg_precipitation_20210826_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL092021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL092021/imerg_precipitation_20210826_1200.npy 40000
# 40000
# /home/fun/data/AL092021/imerg_precipitation_20210826_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL092021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL092021/imerg_precipitation_20210827_0000.npy 40000
# 40000
# /home/fun/data/AL092021/imerg_precipitation_20210827_0600.npy 40000
# 40000
# /home/fun/data/AL092021/imerg_precipitation_20210827_1200.npy 40000
# 40000
# /home/fun/data/AL092021/imerg_precipitation_20210827_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL092021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL092021 max wind  <function get_max_wind at 0x7fe150a89378>
# APPENDED /home/fun/data/AL092021  highest_wind [None 65.0 80.0 75.0 70.0 70.0 80.0 120.0 85.0 105.0 100.0 90.0 125.0 70.0
#  120.0 80.0 85.0 110.0 75.0 125.0 70.0 65.0 125.0 145.0 90.0 110.0 105.0
#  125.0 125.0 145.0 125.0 65.0 75.0 90.0 100.0 80.0 70.0 155.0 160.0 100.0
#  65.0 105.0 75.0 65.0 150.0 80.0 65.0 70.0 75.0 110.0 135.0 75.0 125.0
#  75.0 115.0 125.0 115.0 65.0 115.0 75.0 75.0 85.0 65.0 70.0 65.0 120.0
#  100.0 75.0 80.0 95.0 70.0 90.0 70.0 100.0 80.0 100.0 75.0 85.0 70.0 75.0
#  105.0 65.0 110.0 135.0 75.0 70.0 145.0 120.0 100.0 95.0 155.0 135.0 90.0
#  70.0 90.0 65.0 65.0 110.0 90.0 80.0 65.0 80.0 75.0 70.0 65.0 130.0]
# <class 'numpy.ndarray'>
# category  {'TD': ['20210827', '20210828', '20210829', '20210830', '20210831', '20210901'], 'TS': ['20210830', '20210831']}
# days: ['20210827' '20210830']
# <class 'numpy.ndarray'>
# category  {'TD': ['20210828', '20210829'], 'TS': ['20210829', '20210830', '20210831']}
# days: ['20210828' '20210829']
# <class 'numpy.ndarray'>
# category  {'TD': ['20210831'], 'TS': ['20210901', '20210902'], 'Category_1': ['20210902', '20210903', '20210909', '20210910', '20210911'], 'Category_2': ['20210903', '20210907', '20210908', '20210909'], 'Category_3': ['20210904', '20210905', '20210906', '20210907']}
# days: ['20210831' '20210901' '20210902' '20210903' '20210904']
# /home/fun/data/AL122021/imerg_precipitation_20210831_1800.npy 40000
# 40000
# (1, 200, 183) /home/fun/data/AL122021
# 36600
# /home/fun/data/AL122021/imerg_precipitation_20210901_0000.npy 40000
# 40000
# /home/fun/data/AL122021/imerg_precipitation_20210901_0600.npy 40000
# 40000
# /home/fun/data/AL122021/imerg_precipitation_20210901_1200.npy 40000
# 40000
# /home/fun/data/AL122021/imerg_precipitation_20210901_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL122021
# 40000
# 40000
# (200, 200, 3)
# /home/fun/data/AL122021/imerg_precipitation_20210902_0000.npy 40000
# 40000
# /home/fun/data/AL122021/imerg_precipitation_20210902_0600.npy 40000
# 40000
# /home/fun/data/AL122021/imerg_precipitation_20210902_1200.npy 40000
# 40000
# /home/fun/data/AL122021/imerg_precipitation_20210902_1800.npy 40000
# 40000
# (1, 200, 200) /home/fun/data/AL122021
# 40000
# 40000
# (200, 200, 3)
# <class 'numpy.ndarray'>
# category  {'TS': ['20210908', '20210909']}
# days: ['20210908']
# <class 'numpy.ndarray'>
# category  {'TS': ['20210912', '20210913'], 'Category_1': ['20210914']}
# days: ['20210912' '20210914']
# <class 'numpy.ndarray'>
# category  {'TD': ['20210916', '20210917', '20210926'], 'TS': ['20210917', '20210918', '20210919', '20210920', '20210921', '20210922', '20210923', '20210924', '20210925', '20210926']}
# days: ['20210916' '20210917']
# <class 'numpy.ndarray'>
# category  {'TD': ['20210919', '20210921', '20210922'], 'TS': ['20210919', '20210920', '20210921']}
# days: ['20210919' '20210919']
# <class 'numpy.ndarray'>
# category  {'TD': ['20210919', '20210922', '20210923', '20210924'], 'TS': ['20210919', '20210920', '20210921', '20210922']}
# days: ['20210919' '20210919']
# <class 'numpy.ndarray'>
# category  {'TD': ['20210922', '20210923'], 'TS': ['20210923', '20210924', '20211006', '20211007'], 'Category_1': ['20210924', '20211004', '20211005'], 'Category_2': ['20210925', '20211003', '20211004'], 'Category_3': ['20210925', '20210927', '20210928', '20211002', '20211003'], 'Category_4': ['20210925', '20210926', '20210927', '20210928', '20210929', '20210930', '20211001', '20211002']}
# days: ['20210922' '20210923' '20210924' '20210925' '20210925' '20210925']
# /home/fun/data/AL182021/imerg_precipitation_20210922_1800.npy 40000
# 40000
# /home/fun/data/AL182021/imerg_precipitation_20210923_0000.npy 40000
# 40000
# /home/fun/data/AL182021/imerg_precipitation_20210923_0600.npy 40000
# 40000
# /home/fun/data/AL182021/imerg_precipitation_20210923_1200.npy 40000
# 40000
# /home/fun/data/AL182021/imerg_precipitation_20210923_1800.npy 40000
# 40000
# /home/fun/data/AL182021/imerg_precipitation_20210924_0000.npy 40000
# 40000
# /home/fun/data/AL182021/imerg_precipitation_20210924_0600.npy 40000
# 40000
# /home/fun/data/AL182021/imerg_precipitation_20210924_1200.npy 40000
# 40000
# /home/fun/data/AL182021/imerg_precipitation_20210924_1800.npy 40000
# 40000
# <class 'numpy.ndarray'>
# category  {'TD': ['20210924', '20210925', '20210926'], 'TS': ['20210924', '20210925']}
# days: ['20210924' '20210924']
# <class 'numpy.ndarray'>
# category  {'TD': ['20210929', '20211002', '20211003', '20211004'], 'TS': ['20210929', '20210930', '20211001', '20211002']}
# days: ['20210929' '20210929']
# <class 'numpy.ndarray'>
# category  {'TS': ['20211025', '20211026', '20211027', '20211028', '20211029', '20211030', '20211031', '20211101', '20211102', '20211103', '20211104', '20211105', '20211106', '20211107', '20211108']}
# days: ['20211025']
# (105, 200, 200, 3) (105, 200, 200, 3) (105, 200, 200, 3) (105,)

# %%
stages = [stage_1, stage_2, stage_3]

for stage in stages:
    for i in range(stage.shape[0]):
        for j in range(stage.shape[1]):
            scaler = StandardScaler()
            scaler.fit(stage[i, j, :, :])
            stage[i, j, :, :] = scaler.transform(stage[i, j, :, :])
        
print(stage_1.shape, stage_2.shape, stage_3.shape)
# Out:
# (105, 200, 3, 200) (105, 200, 3, 200) (105, 200, 3, 200)

# %%
# works for now, will clean up later

highest_wind = highest_wind.astype("float32")

stage_1 = stage_1.astype("float32")
stage_1 = np.swapaxes(stage_1, 1, 2)
stage_1 = np.swapaxes(stage_1, 2, 3)

stage_2 = stage_2.astype("float32")
stage_2 = np.swapaxes(stage_2, 1, 2)
stage_2 = np.swapaxes(stage_2, 2, 3)

stage_3 = stage_3.astype("float32")
stage_3 = np.swapaxes(stage_3, 1, 2)
stage_3 = np.swapaxes(stage_3, 2, 3)

print(stage_1.shape, stage_2.shape, stage_3.shape)
# Out:
# (105, 200, 200, 3) (105, 200, 200, 3) (105, 200, 200, 3)

# %%
# img
indices = np.arange(0, stage_1.shape[0], 1)
print(len(indices))
print(len(highest_wind))

index_train, index_test, y_train, y_test = train_test_split(
    indices, highest_wind, train_size = 0.8, random_state = 2309)

stage_1_train = None
stage_1_test = None

for i in index_train: # get shuffled training datasets
    if stage_1_train is None:
        stage_1_train = stage_1[i:i+1, :, :, :] # i:i+1 to force shape of a 4D tensor, doesn't change index values
        stage_2_train = stage_2[i:i+1, :, :, :]
        stage_3_train = stage_3[i:i+1, :, :, :]
        
    else:
        stage_1_train = np.append(stage_1_train, stage_1[i:i+1, :, :, :], axis = 0)
        stage_2_train = np.append(stage_2_train, stage_2[i:i+1, :, :, :], axis = 0)
        stage_3_train = np.append(stage_3_train, stage_3[i:i+1, :, :, :], axis = 0)

for i in index_test: # get shuffled testing datasets
    if stage_1_test is None:
        stage_1_test = stage_1[i:i+1, :, :, :]
        stage_2_test = stage_2[i:i+1, :, :, :]
        stage_3_test = stage_3[i:i+1, :, :, :]
        
    else:
        stage_1_test = np.append(stage_1_test, stage_1[i:i+1, :, :, :], axis = 0)
        stage_2_test = np.append(stage_2_test, stage_2[i:i+1, :, :, :], axis = 0)
        stage_3_test = np.append(stage_3_test, stage_3[i:i+1, :, :, :], axis = 0)

print(stage_1_train.shape, len(y_train))
print(stage_1_test.shape, len(y_test))

print(y_train, y_test)

print(index_train[0])
# Out:
# 105
# 105
# (84, 200, 200, 3) 84
# (21, 200, 200, 3) 21
# [ 80. 115. 155. 125.  75.  65.  70. 110.  90. 110.  65.  75.  70.  95.
#  135. 110.  75. 120.  70. 105.  65. 100. 150.  70. 135. 125.  80.  90.
#   65. 100.  80. 115.  75.  65.  90. 145.  65. 145.  75. 105. 110.  70.
#   80.  90.  90. 155.  75.  70.  70. 100.  80.  75. 100. 135. 120.  80.
#   80. 120.  70.  70.  75.  85. 120. 125.  65.  70.  75. 125.  75. 125.
#   90.  65. 125. 145. 125.  65. 115. 160. 110.  75.  75.  70.  65.  80.] [ 90.  85. 105. 100.  85. 100. 105.  65.  65.  80. 100.  85.  75. 125.
#   65.  70.  70.  75. 130.  65.  95.]
# 14

# %%
# stage 1 of hurricane development -- early input data

channels = 3

stage1_input = Input(shape = (200, 200, channels),
                      name = 'stage1_input')

stage1_conv1 = Conv2D(filters = 64, 
               kernel_size = (3, 3), 
               activation = LeakyReLU(alpha=0.3), 
               padding = "same", 
               name = 'stage1_conv1')(stage1_input)

stage1_pool1 = MaxPooling2D(pool_size = (2,2), 
                         strides = 2,
                         name = 'stage1_pool1')(stage1_conv1)

stage1_batch1 = BatchNormalization(name = 'stage1_batch1')(stage1_pool1)

stage1_conv2 = Conv2D(filters = 128, 
               kernel_size = (3, 3), 
               activation = LeakyReLU(alpha=0.3), 
               padding = "same", 
               name = 'stage1_conv2')(stage1_batch1)

stage1_pool2 = MaxPooling2D(pool_size = (2,2), 
                         strides = 2,
                         name = 'stage1_pool2')(stage1_conv2)

stage1_batch2 = BatchNormalization(name = 'stage1_batch2')(stage1_pool2)

stage1_flat = Flatten(name = 'stage1_flat')(stage1_batch2)


# stage 2

stage2_input = Input(shape = (200, 200, channels),
                      name = 'stage2_input')

stage2_conv1 = Conv2D(filters = 64, 
               kernel_size = (3, 3), 
               activation = LeakyReLU(alpha=0.3), 
               padding = "same", 
               name = 'stage2_conv1')(stage2_input)

stage2_pool1 = MaxPooling2D(pool_size = (2,2), 
                         strides = 2,
                         name = 'stage2_pool1')(stage2_conv1)

stage2_batch1 = BatchNormalization(name = 'stage2_batch1')(stage2_pool1)

stage2_conv2 = Conv2D(filters = 128, 
               kernel_size = (3, 3), 
               activation = LeakyReLU(alpha=0.3), 
               padding = "same", 
               name = 'stage2_conv2')(stage2_batch1)

stage2_pool2 = MaxPooling2D(pool_size = (2,2), 
                         strides = 2,
                         name = 'stage2_pool2')(stage2_conv2)

stage2_batch2 = BatchNormalization(name = 'stage2_batch2')(stage2_pool2)

stage2_flat = Flatten(name = 'stage2_flat')(stage2_batch2)

# stage 3

stage3_input = Input(shape = (200, 200, channels),
                      name = 'stage3_input')

stage3_conv1 = Conv2D(filters = 64, 
               kernel_size = (3, 3), 
               activation = LeakyReLU(alpha=0.3), 
               padding = "same", 
               name = 'stage3_conv1')(stage3_input)

stage3_pool1 = MaxPooling2D(pool_size = (2,2), 
                         strides = 2,
                         name = 'stage3_pool1')(stage3_conv1)

stage3_batch1 = BatchNormalization(name = 'stage3_batch1')(stage3_pool1)

stage3_conv2 = Conv2D(filters = 128, 
               kernel_size = (3, 3), 
               activation = LeakyReLU(alpha=0.3), 
               padding = "same", 
               name = 'stage3_conv2')(stage3_batch1)

stage3_pool2 = MaxPooling2D(pool_size = (2,2), 
                         strides = 2,
                         name = 'stage3_pool2')(stage3_conv2)

stage3_batch2 = BatchNormalization(name = 'stage3_batch2')(stage3_pool2)

stage3_flat = Flatten(name = 'stage3_flat')(stage3_batch2)

# dense layers -- feature training

concat = concatenate([
#             stage1_flat, 
#             stage2_flat, 
            stage3_flat
        ])

dense1 = Dense(128, activation = LeakyReLU(alpha=0.3), name = 'Fully_Connected_1')(concat)
dense1dropout = Dropout(0.5, name = 'Dense_Dropout_1')(dense1)

dense2 = Dense(64, activation = LeakyReLU(alpha=0.3), name = 'Fully_Connected_2')(dense1dropout)
dense2dropout = Dropout(0.5, name = 'Dense_Dropout_2')(dense2)

output = Dense(1, activation = LeakyReLU(alpha=0.3), name = 'Output_Layer')(dense2dropout)

# create model with two inputs
model = Model([
#     stage1_input, 
#     stage2_input, 
    stage3_input
], output)

model.summary()
# Out:
# Model: "model_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# stage3_input (InputLayer)    [(None, 200, 200, 3)]     0
# _________________________________________________________________
# stage3_conv1 (Conv2D)        (None, 200, 200, 64)      1792
# _________________________________________________________________
# stage3_pool1 (MaxPooling2D)  (None, 100, 100, 64)      0
# _________________________________________________________________
# stage3_batch1 (BatchNormaliz (None, 100, 100, 64)      256
# _________________________________________________________________
# stage3_conv2 (Conv2D)        (None, 100, 100, 128)     73856
# _________________________________________________________________
# stage3_pool2 (MaxPooling2D)  (None, 50, 50, 128)       0
# _________________________________________________________________
# stage3_batch2 (BatchNormaliz (None, 50, 50, 128)       512
# _________________________________________________________________
# stage3_flat (Flatten)        (None, 320000)            0
# _________________________________________________________________
# concatenate_22 (Concatenate) (None, 320000)            0
# _________________________________________________________________
# Fully_Connected_1 (Dense)    (None, 128)               40960128
# _________________________________________________________________
# Dense_Dropout_1 (Dropout)    (None, 128)               0
# _________________________________________________________________
# Fully_Connected_2 (Dense)    (None, 64)                8256
# _________________________________________________________________
# Dense_Dropout_2 (Dropout)    (None, 64)                0
# _________________________________________________________________
# Output_Layer (Dense)         (None, 1)                 65
# =================================================================
# Total params: 41,044,865
# Trainable params: 41,044,481
# Non-trainable params: 384
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='dense_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.compile(
    loss = keras.losses.MeanSquaredError(), 
    optimizer = tf.keras.optimizers.Adam(
        learning_rate=0.0001,),
    metrics = tf.keras.metrics.RootMeanSquaredError()
)

history = model.fit([
    #stage_1_train, 
    #stage_2_train, 
    stage_3_train
], y_train, 
          batch_size = 5, 
          epochs = 10, 
          validation_data = ([
              #stage_1_test, 
              #stage_2_test, 
              stage_3_test
          ], y_test), 
          )

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('no wavelet model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], 
           loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# 17/17 [==============================] - 12s 657ms/step - loss: 6077.6025 - root_mean_squared_error: 77.9590 - val_loss: 6317.8994 - val_root_mean_squared_error: 79.4852
# Epoch 2/10
# 17/17 [==============================] - 11s 654ms/step - loss: 4680.6191 - root_mean_squared_error: 68.4151 - val_loss: 6179.9165 - val_root_mean_squared_error: 78.6124
# Epoch 3/10
# 17/17 [==============================] - 11s 645ms/step - loss: 4428.2510 - root_mean_squared_error: 66.5451 - val_loss: 5626.0674 - val_root_mean_squared_error: 75.0071
# Epoch 4/10
# 17/17 [==============================] - 10s 616ms/step - loss: 3721.9631 - root_mean_squared_error: 61.0079 - val_loss: 5395.3774 - val_root_mean_squared_error: 73.4532
# Epoch 5/10
# 17/17 [==============================] - 10s 618ms/step - loss: 3178.2996 - root_mean_squared_error: 56.3764 - val_loss: 5170.8931 - val_root_mean_squared_error: 71.9089
# Epoch 6/10
# 17/17 [==============================] - 11s 632ms/step - loss: 3233.0498 - root_mean_squared_error: 56.8599 - val_loss: 4817.5732 - val_root_mean_squared_error: 69.4087
# Epoch 7/10
# 17/17 [==============================] - 12s 726ms/step - loss: 2935.5703 - root_mean_squared_error: 54.1809 - val_loss: 4266.8638 - val_root_mean_squared_error: 65.3212
# Epoch 8/10
# 17/17 [==============================] - 13s 750ms/step - loss: 3030.4211 - root_mean_squared_error: 55.0493 - val_loss: 3964.2175 - val_root_mean_squared_error: 62.9620
# Epoch 9/10
# 17/17 [==============================] - 13s 741ms/step - loss: 3056.2720 - root_mean_squared_error: 55.2836 - val_loss: 3796.4934 - val_root_mean_squared_error: 61.6157
# Epoch 10/10
# 17/17 [==============================] - 13s 738ms/step - loss: 3299.0149 - root_mean_squared_error: 57.4370 - val_loss: 3411.9148 - val_root_mean_squared_error: 58.4116

# %%
y_pred = model.predict([#stage_1_test, 
                        #stage_2_test, 
                        stage_3_test])
y_pred = y_pred.reshape(y_pred.shape[0])

print(y_test)
print(y_pred)

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(y_test, y_pred, s=30, c='b', marker="s", label='predicted')
ax1.scatter(y_test, y_test, s=30, c='r', marker="o", label='actual')
plt.legend(loc='lower right')
plt.show()
# Out:
# [ 90.  85. 105. 100.  85. 100. 105.  65.  65.  80. 100.  85.  75. 125.
#   65.  70.  70.  75. 130.  65.  95.]
# [11.232095 26.96614  38.162407 64.362526 49.14745  41.12025  42.129368
#  17.772474 36.299595 47.046738 41.352642 36.969944 17.243414 34.325108
#  42.352062 38.772762 41.055397 24.07504  12.545537 19.101984 21.71944 ]

# %%
y_pred = model.predict([
    #stage_1_train, 
    #stage_2_train, 
    stage_3_train])
y_pred = y_pred.reshape(y_pred.shape[0])

print(y_train)
print(y_pred)

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(y_train, y_pred, s=30, c='b', marker="s", label='predicted')
ax1.scatter(y_train, y_train, s=30, c='r', marker="o", label='actual')
plt.legend(loc='lower right')
plt.show()
# Out:
# [ 80. 115. 155. 125.  75.  65.  70. 110.  90. 110.  65.  75.  70.  95.
#  135. 110.  75. 120.  70. 105.  65. 100. 150.  70. 135. 125.  80.  90.
#   65. 100.  80. 115.  75.  65.  90. 145.  65. 145.  75. 105. 110.  70.
#   80.  90.  90. 155.  75.  70.  70. 100.  80.  75. 100. 135. 120.  80.
#   80. 120.  70.  70.  75.  85. 120. 125.  65.  70.  75. 125.  75. 125.
#   90.  65. 125. 145. 125.  65. 115. 160. 110.  75.  75.  70.  65.  80.]
# [32.81145  53.123714 75.82251  80.52317  45.021698 52.28336  40.65087
#  41.95651  39.580563 65.22623  23.941465 30.815998 43.202427 68.76255
#  40.63162  36.656673 26.7554   23.747076 46.690662 46.65465  38.937057
#  16.557558 72.37575  37.691193 48.300137 85.800446 48.93083  53.151188
#  32.075912 29.416914 41.316353 59.457386 50.562256 24.220661 63.766483
#  90.86268  31.189564 77.38648  42.148495 34.68304  72.76356  13.946252
#  40.827282 53.79192  50.273045 69.52152  26.40383  44.87929  48.88573
#  62.775234 41.44002  31.187792 45.43624  75.038246 29.492731 44.118988
#  46.13477  50.404476 41.79253  52.12301  20.799181 50.246685 64.24259
#  24.241375 41.000698 31.07039  28.528214 73.73265  38.21595  82.2668
#  43.55765  35.719025 58.997547 90.11026  57.784767 46.2891   54.00926
#  76.42613  61.424732 41.98286  20.43627  40.257812 46.277916 19.686577]

# %%
import math

percent_error = 0
err_vals = []


for i in range(len(y_test)):
    err = ((y_pred[i] - y_test[i])/y_pred[i])*100
    err_vals = np.append(err_vals, abs(err))
    percent_error = percent_error + abs(err)

mean_error = percent_error/len(y_test)

std_dev_err = err_vals - mean_error
std_dev_err = np.power(std_dev_err, 2)
std_dev_sum = np.sum(std_dev_err)

std_dev = math.sqrt(std_dev_sum/len(err_vals))

print("on average, the model's prediction is", mean_error, "% off of the true max wind speed.")
print("the standard deviation of the error is", std_dev, "knots/hr.")

plt.plot(y_test, err_vals, "ro")
# Out:
# on average, the model's prediction is 55.9166219889779 % off of the true max wind speed.
# the standard deviation of the error is 59.22971102183439 knots/hr.

# %%
model.layers[1].get_weights()
# Out:
# [array([[[[-0.06232635, -0.01409743, -0.05943852, ..., -0.06606408,
#            -0.03466058, -0.01595479],
#           [ 0.00992375, -0.06364235, -0.03812229, ..., -0.07316215,
#             0.0916483 ,  0.02761383],
#           [ 0.02887486,  0.06871355,  0.01446165, ...,  0.09136336,
#            -0.00279943, -0.0178464 ],
#           ...,
#           [ 0.0502643 ,  0.08243553,  0.07471819, ...,  0.08607627,
#             0.0522056 ,  0.08479088],
#           [ 0.00565541,  0.04700837, -0.02494655, ..., -0.03212496,
#            -0.00675529,  0.08726563],
#           [-0.0862804 , -0.00220214, -0.04533527, ...,  0.06351544,
#             0.00445444, -0.08455726]],
#
#          [[ 0.05603271, -0.02574426,  0.03994066, ..., -0.03563355,
#            -0.05744164, -0.02879755],
#           [-0.02612041,  0.00310711,  0.00818804, ...,  0.06129697,
#            -0.03282096, -0.04161562],
#           [-0.02871597,  0.08007678, -0.04524576, ..., -0.05796514,
#            -0.0082387 ,  0.02093785],
#           ...,
#           [ 0.09166583,  0.01051589,  0.03234728, ...,  0.05925668,
#            -0.00199088,  0.01194011],
#           [-0.07692108,  0.07141308,  0.07202227, ..., -0.04680087,
#             0.0598412 ,  0.05132886],
#           [ 0.06687601, -0.07495967, -0.08835267, ...,  0.009375  ,
#             0.00587652,  0.02252699]],
#
#          [[ 0.06199353,  0.04587543,  0.07626696, ..., -0.04141155,
#            -0.02562352,  0.04269395],
#           [-0.00965768, -0.0221172 , -0.07651509, ...,  0.06858452,
#             0.02728075, -0.07638113],
#           [-0.03701917,  0.05718048,  0.09334426, ...,  0.0255033 ,
#            -0.04882996, -0.00400454],
#           ...,
#           [ 0.07226106,  0.03827596,  0.09132472, ...,  0.09832032,
#             0.03504043,  0.10123443],
#           [-0.08932652,  0.09210069,  0.03422417, ...,  0.04709382,
#            -0.02760788,  0.04208698],
#           [ 0.05146333,  0.09719367, -0.02515761, ..., -0.00114724,
#             0.0497117 , -0.04501563]]],
#
#
#         [[[ 0.08784013, -0.02606945,  0.03244677, ...,  0.08417223,
#            -0.02504721, -0.05054828],
#           [ 0.00282136, -0.06849724, -0.05797378, ...,  0.06174953,
#            -0.0660887 , -0.08924403],
#           [ 0.02790824, -0.03074118,  0.06688512, ..., -0.03132277,
#             0.07477672,  0.03401485],
#           ...,
#           [-0.01209775, -0.04600859,  0.08973212, ..., -0.08127994,
#            -0.05862515,  0.0003872 ],
#           [-0.09072578,  0.05257904,  0.03164836, ..., -0.015442  ,
#             0.07576207, -0.00127075],
#           [-0.05451418,  0.07832698,  0.01931371, ...,  0.08664904,
#            -0.03915525,  0.03611772]],
#
#          [[ 0.03282097,  0.05963513,  0.10189652, ..., -0.00095617,
#            -0.04516327, -0.07017034],
#           [-0.08558919, -0.04563265, -0.06078413, ..., -0.04681307,
#            -0.04802632,  0.08771417],
#           [-0.05285153,  0.06315064, -0.01980716, ...,  0.09035571,
#             0.0198379 ,  0.05132643],
#           ...,
#           [ 0.03154124, -0.03106862,  0.02094573, ...,  0.03295078,
#             0.05603109,  0.01541161],
#           [ 0.08488927, -0.04740069,  0.08639804, ...,  0.02285999,
#             0.03660101, -0.0384329 ],
#           [-0.08351552, -0.03466904,  0.04018174, ..., -0.05899736,
#            -0.07438858,  0.05149923]],
#
#          [[ 0.06533191,  0.08888221,  0.058943  , ...,  0.01540013,
#            -0.00610423,  0.07408828],
#           [ 0.04274224,  0.06094933,  0.00443755, ...,  0.02589193,
#            -0.04211886, -0.05657127],
#           [-0.02266787, -0.03369128, -0.03432818, ...,  0.09063357,
#             0.09353124,  0.03822792],
#           ...,
#           [ 0.00464138, -0.00983553,  0.01434956, ..., -0.08456905,
#             0.05377269, -0.06483229],
#           [ 0.0533044 ,  0.08954076, -0.08569098, ..., -0.0301648 ,
#             0.09169937, -0.06199127],
#           [ 0.06878663, -0.07631815,  0.06013756, ..., -0.08487752,
#            -0.01886775,  0.01231906]]],
#
#
#         [[[-0.07070658,  0.061323  ,  0.0635823 , ..., -0.02873948,
#            -0.05574512, -0.07678524],
#           [-0.08070676,  0.07409982,  0.02219298, ..., -0.00243364,
#            -0.04040613, -0.00992657],
#           [-0.04116644, -0.00538178, -0.0545759 , ...,  0.02844944,
#            -0.0699397 ,  0.02307925],
#           ...,
#           [ 0.00786214, -0.01820073,  0.06830686, ..., -0.00557936,
#            -0.03171552,  0.03038705],
#           [-0.03014344,  0.02524087,  0.01193958, ...,  0.0798579 ,
#            -0.07877897,  0.09220228],
#           [-0.06691677,  0.05895514, -0.01731189, ...,  0.05458787,
#             0.04267966,  0.06634825]],
#
#          [[ 0.00062209, -0.01971473,  0.01437375, ..., -0.06632555,
#            -0.04908951,  0.02866836],
#           [ 0.0109314 , -0.0528725 ,  0.05456712, ...,  0.00278607,
#            -0.01538703,  0.02988201],
#           [-0.03113354,  0.02894661, -0.0192238 , ...,  0.0061877 ,
#             0.03974985, -0.03937626],
#           ...,
#           [ 0.01358534,  0.07976472, -0.00972218, ...,  0.03395393,
#            -0.01822577, -0.03957678],
#           [ 0.04480885, -0.04618945, -0.03253231, ..., -0.03973623,
#             0.02468443, -0.01954259],
#           [ 0.01997777, -0.03846787, -0.03057183, ..., -0.04418055,
#             0.05751127, -0.01780612]],
#
#          [[ 0.05849003,  0.03712536,  0.04925201, ...,  0.07634739,
#            -0.07323886, -0.00502765],
#           [-0.0595216 ,  0.06855845,  0.02853769, ..., -0.06225738,
#            -0.01212864, -0.03832513],
#           [-0.07385938,  0.08445849,  0.05032906, ...,  0.05959881,
#            -0.07940201,  0.07590713],
#           ...,
#           [ 0.04003654,  0.00379513,  0.02083536, ...,  0.0370823 ,
#             0.06716824,  0.00979732],
#           [ 0.06020885,  0.04457191,  0.0317989 , ...,  0.0375759 ,
#             0.06637258, -0.01935277],
#           [ 0.01801043, -0.07553842,  0.06272106, ...,  0.06030397,
#             0.05352151, -0.02542534]]]], dtype=float32),
#  array([-4.16702824e-05, -8.84030480e-03, -1.59188882e-02, -1.27458293e-02,
#         -1.57779362e-02, -1.05875768e-02, -4.65834374e-03,  4.29101149e-03,
#         -1.21785318e-02, -5.12692495e-04, -4.00960504e-04,  1.38186570e-03,
#         -1.44697465e-02, -1.22308331e-02, -1.41585050e-02,  8.78484827e-03,
#         -1.78537350e-02, -1.34894205e-02,  1.82274170e-03, -1.23256417e-02,
#         -8.93673394e-03, -1.06472177e-02, -1.11162299e-02, -1.25010535e-02,
#          1.17693571e-02, -1.76178906e-02,  1.09838892e-03, -1.65241957e-02,
#         -9.75764915e-03, -9.96620487e-03, -1.69178378e-02, -5.89643791e-03,
#         -7.45598553e-03, -1.41307823e-02, -6.19614404e-03,  9.71575733e-04,
#         -7.52633484e-03, -6.38583023e-03, -5.66177117e-03, -1.00254118e-02,
#         -7.40017090e-03, -9.89126228e-03, -1.69091802e-02, -9.30223381e-04,
#         -7.72438385e-03, -5.17137907e-03, -1.20363263e-02,  1.21782171e-02,
#         -1.17821293e-02, -1.08759701e-02, -1.02336220e-02, -1.11074969e-02,
#         -4.74964175e-03, -1.65270101e-02, -5.64489979e-04, -7.81742670e-03,
#         -3.93625628e-03, -5.34903118e-03, -1.12985428e-02, -5.67317754e-03,
#         -1.05524790e-02, -1.22215459e-02, -1.43582104e-02, -1.69216283e-02],
#        dtype=float32)]

# %%
train_pred = model.predict([stage_1_train, stage_2_train, stage_3_train])
train_pred = train_pred.reshape(train_pred.shape[0])

print(y_train)
print(train_pred)

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(y_train, train_pred, s=30, c='b', marker="s", label='predicted')
ax1.scatter(y_train, y_train, s=30, c='r', marker="o", label='actual')
plt.legend(loc='lower right')
plt.show()
# Out:
# [ 75. 105.  90.  80. 120. 120.  80.  65. 105.  70.  75. 105. 120. 100.
#  125.  85.  75.  75. 145.  80.  85.  90.  75.  80.  65.  70. 105. 125.
#   70.  90.  80.  65. 115. 125. 105. 120.  65.  70.  75. 125. 125.  85.
#  115. 120.  70. 160. 155.  75. 145.  85.  70. 125. 100.  70.  70.  65.
#   95. 105. 110.  65.  75. 120.  70.  80. 135. 115. 100. 100. 110.  90.
#   95.]
# [ 63.621883  74.25207   85.73393   67.40442   89.555214 133.52554
#   77.52279   57.772488  88.896835  55.474697  61.46399   94.492516
#   64.638176  72.78622   83.14689   79.557846  53.02427   78.50034
#  133.23456   74.57247   56.357784  75.53317   64.59409   72.370705
#   59.409122  71.239075 102.14491  125.75788   55.15289   84.044846
#   84.96973   64.877975  99.17434   94.47669   86.30307  104.41352
#   61.956924  57.26902   61.740635  98.68275  114.87965   65.77408
#   84.40147   96.13337   64.0435   144.77728  129.57506   72.338295
#  150.69771   67.365524  57.09145  122.13685  100.74853   58.839634
#   63.547832  59.52152   78.18735   74.03864  105.1167    53.840755
#   69.48751  112.79142   63.570305  70.27213   93.862625  89.29426
#   72.822914  75.210106  94.36487   93.687035  76.2842  ]

# %%
index_test
# Out:
# array([64, 23, 84, 15,  8,  0, 54, 29, 20, 25, 62, 81, 50, 57, 37, 80, 78,
#        40])

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

print("precision: ", precision_score(y_test_spatial, y_pred_round))
print("recall: ", recall_score(y_test_spatial, y_pred_round))
print("f1 score: ", f1_score(y_test_spatial, y_pred_round))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-64ff7bb11dea> in <module>
#       1 from sklearn.metrics import precision_score, recall_score, f1_score
#       2
# ----> 3 print("precision: ", precision_score(y_test_spatial, y_pred_round))
#       4 print("recall: ", recall_score(y_test_spatial, y_pred_round))
#       5 print("f1 score: ", f1_score(y_test_spatial, y_pred_round))
#
# NameError: name 'y_test_spatial' is not defined

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test_spatial, y_pred)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,
                                   estimator_name='true control ROC curve')
display.plot()

plt.show()

# %%
def draw_confusion_matrix(y, yhat, classes):
    plt.cla()
    plt.clf()
    matrix = confusion_matrix(y, yhat)
    plt.imshow(matrix, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("true control confusion matrix")
    plt.colorbar()
    num_classes = len(classes)
    plt.xticks(np.arange(num_classes), classes, rotation=90)
    plt.yticks(np.arange(num_classes), classes)

    fmt = 'd'
    thresh = matrix.max() / 2.
    for i, j in itertools.product(range(matrix.shape[0]), range(matrix.shape[1])):
        plt.text(j, i, format(matrix[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if matrix[i, j] > thresh else "black")

# %%
draw_confusion_matrix(y_test_spatial, y_pred_round, ['Glacial', 'Thermokarst'])
fig = plt.ylabel('True label')
fig = plt.xlabel('Predicted label')
fig = plt.show()

# %%
import json

name = '/home/fun/data/AL202003' + '/profile.json'
f = open(name)
profile = json.load(f)
paths = profile['path']

valid_dates = []
for path in paths:
    valid_dates = np.append(valid_dates, str(path['date']))
    
imergs = glob.glob('/home/fun/data/AL182012/imerg_precipitation_*.npy', recursive = True)
imergs.sort()
imergs = imergs[0:3]
print(len(imergs))

valid = True

days = []

for imerg in imergs:
    days = np.append(days, imerg[-17:-9])
    
for day in days:
    if day not in valid_dates:
        valid = False
        
print(valid, valid_dates, days)
# Out:
# 3
# False ['20031204' '20031204' '20031205' '20031205' '20031205' '20031205'
#  '20031206' '20031206' '20031206' '20031206'] ['20121021' '20121022' '20121022']

# %%
    

a = np.load('/home/fun/data/AL042008/noaa_sst_20080720.npy') * 100




print (a)

print (a.reshape(200, 200))
# Out:
# [[[2482.     2485.9998 2488.     ...      -inf      -inf      -inf]
#   [2475.     2476.9998 2478.     ...      -inf      -inf      -inf]
#   [2471.     2471.     2471.     ...      -inf      -inf      -inf]
#   ...
#   [     -inf      -inf      -inf ... 1884.     1864.     1866.    ]
#   [     -inf      -inf      -inf ... 1782.     1770.9999 1791.    ]
#   [     -inf      -inf      -inf ... 1690.     1699.     1727.    ]]]
# [[2482.     2485.9998 2488.     ...      -inf      -inf      -inf]
#  [2475.     2476.9998 2478.     ...      -inf      -inf      -inf]
#  [2471.     2471.     2471.     ...      -inf      -inf      -inf]
#  ...
#  [     -inf      -inf      -inf ... 1884.     1864.     1866.    ]
#  [     -inf      -inf      -inf ... 1782.     1770.9999 1791.    ]
#  [     -inf      -inf      -inf ... 1690.     1699.     1727.    ]]
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: overflow encountered in multiply
#   """Entry point for launching an IPython kernel.
