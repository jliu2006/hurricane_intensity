# %%
## importing all libraries for our models

# pandas
import pandas as pd

# tensorflow
import tensorflow as tf
from tensorflow import keras

# tensorflow.keras
from keras import Input
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten 
from keras.layers import Conv2D, Conv1D, MaxPooling2D
from keras.layers import AveragePooling2D, AveragePooling1D
from keras.layers import GlobalMaxPooling1D, GlobalAveragePooling2D
from keras.layers import BatchNormalization, LSTM
from keras.layers import Concatenate, concatenate 
# Concatenate returns Concatenate object (layers), concatenate returns Tensor object (arrays)
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical
from keras import backend as K
from keras.constraints import max_norm, non_neg, unit_norm, min_max_norm
from keras.layers.advanced_activations import LeakyReLU
#from tensorflow.keras.utils import plot_model

# numpy
import numpy as np
from numpy import random

# sklearn
import sklearn

# sklearn for pipeline mixins
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator, TransformerMixin

# sklearn for data splitting
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

# sklearn for models
from sklearn.svm import SVC  
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.model_selection import KFold
from sklearn.tree import export_graphviz
from sklearn.preprocessing import normalize

# sklearn for model evaluation
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score, roc_curve, auc, RocCurveDisplay
import sklearn.metrics.cluster as smc

# matplotlib.pyplot for plotting
from matplotlib import pyplot
import matplotlib.pyplot as plt 
import os

# misc
import itertools
from IPython.display import display
import matplotlib.pyplot as plt
import pydot
import graphviz
from PIL import Image
import numpy as np
from numpy import random
import glob
import rasterio as rio
import scipy.io as sio
import glob
import json

# %%
def get_max_wind(hurricane):
    name = hurricane + '/profile.json'
    f = open(name)
    profile = json.load(f)
    paths = profile['path']
    
    cats = []
    thresholds = [(0, 63), (1, 82), (2, 95), (3, 112), (4, 136), (5, 999)] # knots
    
    for path in paths:
        wind_speed = float(path['maxwind'])
        for it in thresholds:
            if wind_speed <= it[1]:
                category = it[0]
                break
        cats = np.append(cats, category)
    highest_cat = max(cats)
    return highest_cat

def get_imerg(imerg):
    # get imerg
    precips = glob.glob(imerg, recursive = True)
    precips.sort()
    print (precips, " precips: ", temperatures)
    imerg_array = np.load(precips[0])
    
    for file in precips[1:10]:
        load = np.load(file)
        print(file, load.shape)
        imerg_array = np.append(imerg_array, load, axis = 0)
    imerg_array = imerg_array.reshape(1, 10, 200, 200)
    
    return imerg_array

def get_sst(sst):
    # get sst
    temperatures = glob.glob(sst, recursive = True)
    print (sst, " temperatures: ", temperatures)
    temperatures.sort()
    sst_array = np.load(temperatures[0])
    
    for file in temperatures[1:4]:
        sst_array = np.append(sst_array, np.load(file), axis = 0)
    sst_array = sst_array.reshape(1, 4, 200, 200)
    
    return sst_array

def get_rgb(rgb):
    # get wavelet decomposed rgb
    colors = glob.glob(rgb, recursive = True)
    print (colors, " rgbs: ", temperatures)
    colors.sort()
    rgb_array = np.load(colors[0])
    
    for file in colors[1:4]:
        rgb_array = np.append(rgb_array, np.load(file), axis = 0)
    
    rgb_array = rgb_array[:, :200, :200]
    rgb_array = rgb_array.reshape(1, 48, 200, 200)
    
    return rgb_array

def lenCheck(imerg, sst, rgb):
    imergs = glob.glob(imerg)
    ssts = glob.glob(sst)
    rgbs = glob.glob(rgb)
    
    if len(imergs) < 10 or len(ssts) < 4 or len(rgbs) < 4:
        return False
    else:
        return True
    
def landCheck(folder, imerg, sst, rgb):
    name = folder + '/profile.json'
    f = open(name)
    profile = json.load(f)
    paths = profile['path']

    valid_dates = []
    for path in paths:
        valid_dates = np.append(valid_dates, str(path['date']))
        
    file = folder + '/noaa_sst_*.npy'

    sst = glob.glob(file, recursive = True)
    sst.sort()
    sst = sst[0:4]
    
    valid = True

    days = []

    for imerg in imergs:
        days = np.append(days, sst[-17:-9])

    for day in days:
        if day not in valid_dates:
            valid = False
        else:
            valid = True

    return valid
    
def createWindMap(profile):
    # return nparray(1, 200, 200)
    # hurricane center is  at (99,99),   each direction expand by 100 miles
    
    res = np.zeros((200, 200))
    
    maxwindradius = min(int(float(profile['maxwindradius'])), 99)
    maxwind = float(profile['maxwind'])
    
    keys = []
    for it in profile.keys():
        if 'kt' in it:
            keys.append(it)        
    keys.sort()
    
    for it in keys:
        if "ne" in it:
            radius = min(int(float(profile[it])), 99)
            for i in range(0, radius):
                for j in range(0, radius):
                    res[100-i-1,  100 +j] = max(0, float(it[:-4]))
        elif "se" in it:
            radius = min(int(float(profile[it])), 99)
            for i in range(0, radius):
                for j in range(0, radius):
                    res[100 + i,  100 +j] = max(0, float(it[:-4]))
        elif "nw" in it:
            radius = min(int(float(profile[it])), 99)
            for i in range(0, radius):
                for j in range(0, radius):
                    res[100-i-1,  100-j-1] = max(0, float(it[:-4]))
        elif "sw" in it:
            radius = min(int(float(profile[it])), 99)
            for i in range(0, radius):
                for j in range(0, radius):
                    res[100 + i,  100-j-1] = max(0, float(it[:-4]))
                        
    for i in range(-maxwindradius, maxwindradius):
        for j in range(-maxwindradius, maxwindradius):
            res[99 + i, 99 + j] = maxwind
    
    res = np.expand_dims(res, axis = 2)
                    
    return res

# %%
def getMaxWindDay(hurr_dict, day_list):
    high_day = None
    high_wind = 0
    for day in day_list: # for every day in a category for a hurricane:
        wind_speeds = np.asarray([])
        for path in hurr_dict: # for every path record in that hurricane's profile.json:
            if day == str(path['date']): # if the days match:
                if float(path['maxwind']) > high_wind: # compare this day's max wind to the highest speed for this category
                    high_wind = float(path['maxwind'])
                    high_day = day
    
    return high_day

def getCategory(wind_speed): # based on the Saffir-Simpson Scale for hurricane classification
    
    thresholds = [('TD', 33), ('TS', 63), ('Category_1', 82), ('Category_2', 95), ('Category_3', 112), ('Category_4', 136)]
    
    for it in thresholds:
        if wind_speed <= it[1]:
            return it[0]
    return thresholds[-1][0]

def selectDay(hurr_dict, cat_dictionary):
    pick_days = []
    for key in cat_dictionary.keys(): # for every category in the category dictionary:
        days = cat_dictionary[key]
        high_day = getMaxWindDay(hurr_dict, days) # find day in each category with the highest average wind speed
        pick_days = np.append(pick_days, high_day) # pick the first (0th index) day of that category
    print("pick days:", pick_days)
    return pick_days # a 1-D array containing the first day that the hurricane reaches a new category.

def lastDay(hurr_dict):
    return None # will pick last day in path, 

def getStageByDay(folder, day):
    
    imerg_names = folder + '/imerg_precipitation_' + day + '_*.npy'
    sst_names = folder + '/noaa_sst_' + day + '*.npy'
    rgb_names = folder + '/10_wavelet_rgb_' + day + '*.npy'
    #rgb_names = folder + '/10_modis_satellite_' + day + '*.npy'
    
    profile_name = folder + '/profile.json'
    f = open(profile_name)
    profile = json.load(f)
    paths = profile['path']

    imergs = glob.glob(imerg_names, recursive = True)
    ssts = glob.glob(sst_names, recursive = True)
    rgbs = glob.glob(rgb_names, recursive = True)
    
    imerg_array = np.zeros((200, 200))
    for imerg in imergs:
        im_arr = np.load(imerg)
        if not (sizeCheck(im_arr)):
            continue
        imerg_array = imerg_array + np.load(imerg)

    imerg_array = imerg_array.reshape(200, 200, 1)
    imerg_array = imerg_array / len(imergs)
    
    if (not rgbs) or (not ssts):
        #print("no rgbs or ssts: ", folder, day)
        return None
    
    
    sst_array = np.load(ssts[0])
    print("sst:", sst_array.shape)
    
    if (not sizeCheck(sst_array)) or (not sizeCheck(imerg_array)):      
        #print("sst shape invalid: ", folder, day)
        return None

    sst_array = sst_array.reshape(200, 200, 1)
    
    rgb_array = np.load(rgbs[0])
    
    #rgb_array = rgb_array[100:300, 100:300, :]
    rgb_array = rgb_array[1:201, 1:201, :]
    print(folder, day, "- rgb:", rgb_array.shape)
    rgb_array = ((rgb_array * 10000 + 100) / 66.66)*1.5


    rgb_array = rgb_array.astype(int)

    rgb_array[rgb_array < 0] = 0
    rgb_array[rgb_array > 255] = 255
        
    selected_days = []

    for path in paths:
        if path['date'] == int(day):
            selected_days.append(path)
        
    # pick mid element from path    
    middleIndex = int((len(selected_days) - 1)/2)
    if len(selected_days) == 2: 
        middleIndex = 1
        
    selected_day = selected_days[middleIndex]

    wind_array = createWindMap(selected_day)
    
    stage_array = imerg_array
    stage_array = np.dstack((stage_array, sst_array))
    stage_array = np.dstack((stage_array, rgb_array))
    stage_array = np.dstack((stage_array, wind_array))
    stage_array = np.expand_dims(stage_array, axis = 0)
    
    return stage_array

def sizeCheck(tensor): # size check should happen after stage data is collected
    shape = len(tensor.flatten())
    if shape != 40000:
        return False
    else:
        return True
    
def populateStage(stage, step):
    if step is None:
        return stage
    if stage is None:
        stage = step
    else:
        stage = np.append(stage, step, axis = 0)
    return stage

# %%
def completeDataCollection(globname, img_size, hours_early, max_wind_param, landed_only): # NEW DATA COLLECTION METHOD - SORT INTO STAGES

    folders = glob.glob(globname, recursive = True)
    # AL032000, failed rgb glob (no modis satellite data for that day)
    # AL242005, failed ssts glob (no sst satellite data for that day)
    stage_1 = None
    stage_2 = None
    stage_3 = None
    highest_cat = None

    for folder in folders:
    
        name = folder + '/profile.json'
        f = open(name)
        prof = json.load(f)
        paths = prof['path']
        
        print(folder)
        '''
        if landed_only:
            if "landed" not in prof.keys() or not prof['landed']:
                continue
        '''
        cats = {} # dictionary with categories as keys, days as values.
        # used to extract day values based on hurricane category (stage)
        
        remove = int((int(hours_early)-6)/6) # number of 6-hourly path records to remove from profile.json
        paths = paths[:-remove] # removal is done in-place
        
        for path in paths:
            if int(path['maxwind']) < int(max_wind_param): # only select hurricanes with wind speed at least max_wind_param
                continue
            # getCategory will take the max wind of every day in a hurricane's path and turn it into a category
                # based on the Saffir-Simpson Scale
            test = getCategory(int(path['maxwind']))

            if test not in cats.keys():
                cats[test] = []
            cats[test].append(str(path['date']))

        for key in cats.keys():
            cats[key] = list(set(cats[key]))
            cats[key].sort()
        
        # the category dictionary is used to select a day
        days = selectDay(paths, cats) # pass the profile.json of the hurricane to selectDay
            # selectDay will then pass the profile to getMaxWindDay
            # getMaxWindDay will use the profile combined with the cat_dictionary to get the day with highest wind

        if len(days) < 3:
            #print("not enough categories: ", folder)
            continue
        #print("valid folder: ", folder)

        # this is the part of the model that selects the category
        # the step before this, selectDays(cat_dictionary), takes the list of days in a hurricane,
            # which is already sorted with a dictionary by category, and picks the middle day in each category's list
            # to produce days, which is used in this step.
        step_1 = getStageByDay(folder, days[-3]) # third last day (category)
        step_2 = getStageByDay(folder, days[-2]) # second last
        step_3 = getStageByDay(folder, days[-1]) # last (strongest category)


        if (step_1 is None) or (step_2 is None) or (step_3 is None):
            #print("size not fit: ", folder)
            continue

        highest_cat = np.append(highest_cat, get_max_wind(folder))
        
        stage_1 = populateStage(stage_1, step_1)
        stage_2 = populateStage(stage_2, step_2)
        stage_3 = populateStage(stage_3, step_3)
        
        print("APPENDED", folder)

        

    highest_cat = highest_cat[1:]
    
    # original tensor size along dimensions 1 and 2 is 200x200
    length = stage_1.shape[1]
    padding = int((length - img_size)/2)
    
    stage_1 = stage_1[:, padding:length-padding, padding:length-padding, :]
    stage_2 = stage_2[:, padding:length-padding, padding:length-padding, :]
    stage_3 = stage_3[:, padding:length-padding, padding:length-padding, :]
    
    print(#stage_1.shape, 
      #stage_2.shape,
      stage_3.shape, 
      highest_cat.shape
     )
    
    return stage_1, stage_2, stage_3, highest_cat

# %%
stage_1, stage_2, stage_3, highest_cat = completeDataCollection('/home/fun/data/AL*20*', 100, 24, 0, True)
# Out:
# /home/fun/data/AL022004
# pick days: ['20040809' '20040811']
# /home/fun/data/AL042004
# pick days: ['20040820' '20040818' '20040815' '20040816']
# sst: (1, 200, 200)
# /home/fun/data/AL042004 20040818 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL042004 20040815 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL042004 20040816 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL042004
# /home/fun/data/AL052004
# pick days: ['20040814' '20040814']
# /home/fun/data/AL072004
# pick days: ['20040828' '20040828']
# /home/fun/data/AL082004
# pick days: ['20040829' '20040830']
# /home/fun/data/AL102004
# pick days: ['20040909']
# /home/fun/data/AL112004
# pick days: []
# /home/fun/data/AL072006
# pick days: ['20060905' '20060910' '20060910']
# sst: (1, 200, 200)
# /home/fun/data/AL072006 20060905 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072006 20060910 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072006 20060910 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL072006
# /home/fun/data/AL012000
# pick days: ['20000607']
# /home/fun/data/AL022000
# pick days: ['20000623']
# /home/fun/data/AL032000
# pick days: ['20000804' '20000814' '20000813' '20000812' '20000812']
# /home/fun/data/AL042000
# pick days: ['20000808']
# /home/fun/data/AL052000
# pick days: ['20000814' '20000814']
# /home/fun/data/AL062000
# pick days: ['20000818' '20000818']
# /home/fun/data/AL072000
# pick days: ['20000820' '20000821' '20000821']
# sst: (1, 200, 200)
# /home/fun/data/AL072000 20000820 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072000 20000821 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072000 20000821 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL072000
# /home/fun/data/AL082000
# pick days: ['20000902' '20000902']
# /home/fun/data/AL092000
# pick days: ['20000908']
# /home/fun/data/AL102000
# pick days: ['20000911' '20000911' '20000916']
# sst: (1, 200, 200)
# /home/fun/data/AL102000 20000911 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102000 20000911 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102000 20000916 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL102000
# /home/fun/data/AL112000
# pick days: ['20000915' '20000916' '20000917']
# sst: (1, 200, 200)
# /home/fun/data/AL112000 20000915 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112000 20000916 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112000 20000917 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL112000
# /home/fun/data/AL122000
# pick days: ['20000921' '20000921']
# /home/fun/data/AL132000
# pick days: ['20000921' '20000923' '20000927' '20000929' '20000928' '20000928']
# sst: (1, 200, 200)
# /home/fun/data/AL132000 20000929 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132000 20000928 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132000 20000928 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL132000
# /home/fun/data/AL142000
# pick days: ['20000925' '20000929' '20000928']
# sst: (1, 200, 200)
# /home/fun/data/AL142000 20000925 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142000 20000929 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142000 20000928 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL142000
# /home/fun/data/AL152000
# pick days: ['20000929' '20000930' '20000930' '20001001' '20001001']
# sst: (1, 200, 200)
# /home/fun/data/AL152000 20000930 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152000 20001001 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152000 20001001 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL152000
# /home/fun/data/AL162000
# pick days: ['20001005' '20001006']
# /home/fun/data/AL172000
# pick days: ['20001015' '20001017' '20001019' '20001019']
# sst: (1, 200, 200)
# /home/fun/data/AL172000 20001017 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172000 20001019 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172000 20001019 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL172000
# /home/fun/data/AL182000
# pick days: ['20001020' '20001021']
# /home/fun/data/AL192000
# pick days: ['20001025' '20001028']
# /home/fun/data/AL012001
# pick days: []
# /home/fun/data/AL022001
# pick days: ['20010711']
# /home/fun/data/AL032001
# pick days: ['20010802' '20010802']
# /home/fun/data/AL042001
# pick days: ['20010815' '20010819']
# /home/fun/data/AL052001
# pick days: ['20010827' '20010823']
# /home/fun/data/AL062001
# pick days: ['20010902' '20010908' '20010909' '20010909' '20010909']
# sst: (1, 200, 200)
# /home/fun/data/AL062001 20010909 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL062001 20010909 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL062001 20010909 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL062001
# /home/fun/data/AL072001
# pick days: ['20010911' '20010917' '20010913' '20010914' '20010914']
# sst: (1, 200, 200)
# /home/fun/data/AL072001 20010913 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072001 20010914 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072001 20010914 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL072001
# /home/fun/data/AL082001
# pick days: ['20010913' '20010913']
# /home/fun/data/AL092001
# pick days: []
# /home/fun/data/AL102001
# pick days: ['20010922' '20010923' '20010926' '20010926']
# sst: (1, 200, 200)
# /home/fun/data/AL102001 20010923 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102001 20010926 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102001 20010926 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL102001
# /home/fun/data/AL112001
# pick days: ['20011005' '20011006' '20011008' '20011008']
# sst: (1, 200, 200)
# /home/fun/data/AL112001 20011006 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112001 20011008 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112001 20011008 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL112001
# /home/fun/data/AL122001
# pick days: ['20011006' '20011007']
# /home/fun/data/AL132001
# pick days: ['20011011' '20011014' '20011014']
# sst: (1, 200, 200)
# /home/fun/data/AL132001 20011011 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132001 20011014 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132001 20011014 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL132001
# /home/fun/data/AL142001
# pick days: ['20011027' '20011030']
# /home/fun/data/AL152001
# pick days: ['20011029' '20011102' '20011105' '20011103' '20011103' '20011104']
# sst: (1, 200, 200)
# /home/fun/data/AL152001 20011103 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152001 20011103 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152001 20011104 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL152001
# /home/fun/data/AL162001
# pick days: ['20011105' '20011105']
# /home/fun/data/AL172001
# pick days: ['20011130' '20011126' '20011127']
# sst: (1, 200, 200)
# /home/fun/data/AL172001 20011130 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172001 20011126 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172001 20011127 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL172001
# /home/fun/data/AL012002
# pick days: ['20020715' '20020716']
# /home/fun/data/AL022002
# pick days: []
# /home/fun/data/AL032002
# pick days: ['20020806' '20020808']
# /home/fun/data/AL042002
# pick days: ['20020829' '20020830']
# /home/fun/data/AL052002
# pick days: ['20020902' '20020903']
# /home/fun/data/AL062002
# pick days: ['20020905' '20020906']
# /home/fun/data/AL072002
# pick days: ['20020907']
# /home/fun/data/AL082002
# pick days: ['20020908' '20020911' '20020911']
# sst: (1, 200, 200)
# /home/fun/data/AL082002 20020908 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL082002 20020911 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL082002 20020911 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL082002
# /home/fun/data/AL092002
# pick days: ['20020912' '20020913']
# /home/fun/data/AL102002
# pick days: ['20020918' '20020919' '20020921' '20020921' '20020921']
# sst: (1, 200, 200)
# /home/fun/data/AL102002 20020921 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102002 20020921 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102002 20020921 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL102002
# /home/fun/data/AL112002
# pick days: ['20020918' '20020918']
# /home/fun/data/AL122002
# pick days: ['20020921' '20020928' '20020926']
# sst: (1, 200, 200)
# /home/fun/data/AL122002 20020921 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122002 20020928 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122002 20020926 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL122002
# /home/fun/data/AL132002
# pick days: ['20020927' '20020930' '20021001' '20021002' '20021002' '20021002']
# sst: (1, 200, 200)
# /home/fun/data/AL132002 20021002 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132002 20021002 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132002 20021002 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL132002
# /home/fun/data/AL142002
# pick days: ['20021014']
# /home/fun/data/AL012003
# pick days: ['20030426' '20030421']
# /home/fun/data/AL022003
# pick days: ['20030611']
# /home/fun/data/AL032003
# pick days: ['20030629' '20030630']
# /home/fun/data/AL042003
# pick days: ['20030707' '20030710' '20030710']
# sst: (1, 200, 200)
# /home/fun/data/AL042003 20030707 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL042003 20030710 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL042003 20030710 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL042003
# /home/fun/data/AL052003
# pick days: ['20030720' '20030718' '20030718']
# sst: (1, 200, 200)
# /home/fun/data/AL052003 20030720 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL052003 20030718 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL052003 20030718 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL052003
# /home/fun/data/AL062003
# pick days: ['20030719']
# /home/fun/data/AL072003
# pick days: []
# /home/fun/data/AL082003
# pick days: ['20030815']
# /home/fun/data/AL092003
# pick days: ['20030821']
# /home/fun/data/AL102003
# pick days: ['20030828' '20030829' '20030830' '20030830' '20030831' '20030901']
# sst: (1, 200, 200)
# /home/fun/data/AL102003 20030830 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102003 20030831 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102003 20030901 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL102003
# /home/fun/data/AL112003
# pick days: ['20030830']
# /home/fun/data/AL122003
# pick days: ['20030905' '20030905']
# /home/fun/data/AL132003
# pick days: ['20030906' '20030907' '20030908' '20030908' '20030910' '20030911']
# sst: (1, 200, 200)
# /home/fun/data/AL132003 20030908 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132003 20030910 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132003 20030911 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL132003
# /home/fun/data/AL142003
# pick days: ['20030909']
# /home/fun/data/AL152003
# pick days: ['20030924' '20030926' '20030927' '20030927']
# sst: (1, 200, 200)
# /home/fun/data/AL152003 20030926 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152003 20030927 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152003 20030927 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL152003
# /home/fun/data/AL162003
# pick days: ['20030927' '20030929' '20031003' '20031003' '20031004']
# sst: (1, 200, 200)
# /home/fun/data/AL162003 20031003 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL162003 20031003 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL162003 20031004 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL162003
# /home/fun/data/AL172003
# pick days: ['20030930' '20031003']
# /home/fun/data/AL182003
# pick days: ['20031010' '20031012']
# /home/fun/data/AL192003
# pick days: ['20031014' '20031017']
# /home/fun/data/AL202003
# pick days: ['20031204' '20031206']
# /home/fun/data/AL212003
# pick days: ['20031209' '20031210']
# /home/fun/data/AL012004
# pick days: ['20040801' '20040803' '20040804' '20040805' '20040805']
# sst: (1, 200, 200)
# /home/fun/data/AL012004 20040804 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL012004 20040805 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL012004 20040805 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL012004
# /home/fun/data/AL032004
# pick days: ['20040810' '20040811' '20040812' '20040813' '20040813']
# sst: (1, 200, 200)
# /home/fun/data/AL032004 20040812 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL032004 20040813 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL032004 20040813 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL032004
# /home/fun/data/AL062004
# pick days: ['20040825' '20040826' '20040827' '20040903' '20040831' '20040831']
# sst: (1, 200, 200)
# /home/fun/data/AL062004 20040903 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL062004 20040831 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL062004 20040831 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL062004
# /home/fun/data/AL092004
# pick days: ['20040903' '20040905' '20040905' '20040906' '20040906' '20040911']
# sst: (1, 200, 200)
# /home/fun/data/AL092004 20040906 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL092004 20040906 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL092004 20040911 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL092004
# /home/fun/data/AL122004
# pick days: ['20040916' '20040926' '20040918' '20040919' '20040921' '20040921']
# sst: (1, 200, 200)
# /home/fun/data/AL122004 20040919 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122004 20040921 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122004 20040921 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL122004
# /home/fun/data/AL132004
# pick days: ['20040920' '20041002' '20041002']
# sst: (1, 200, 200)
# /home/fun/data/AL132004 20040920 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132004 20041002 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132004 20041002 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL132004
# /home/fun/data/AL142004
# pick days: ['20041008' '20041009']
# /home/fun/data/AL152004
# pick days: ['20041010']
# /home/fun/data/AL162004
# pick days: ['20041126' '20041129']
# /home/fun/data/AL012005
# pick days: ['20050609' '20050611']
# /home/fun/data/AL022005
# pick days: ['20050628']
# /home/fun/data/AL032005
# pick days: []
# /home/fun/data/AL042005
# pick days: []
# /home/fun/data/AL052005
# pick days: ['20050711' '20050713']
# /home/fun/data/AL062005
# pick days: ['20050721' '20050723']
# /home/fun/data/AL072005
# pick days: ['20050724']
# /home/fun/data/AL082005
# pick days: ['20050803' '20050804']
# /home/fun/data/AL092005
# pick days: ['20050807' '20050813' '20050816' '20050816']
# sst: (1, 200, 200)
# /home/fun/data/AL092005 20050813 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL092005 20050816 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL092005 20050816 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL092005
# /home/fun/data/AL102005
# pick days: ['20050813']
# /home/fun/data/AL112005
# pick days: []
# /home/fun/data/AL122005
# pick days: ['20050824' '20050825']
# /home/fun/data/AL132005
# pick days: ['20050831' '20050831']
# /home/fun/data/AL142005
# pick days: ['20050902' '20050904' '20050906' '20050906' '20050906']
# sst: (1, 200, 200)
# /home/fun/data/AL142005 20050906 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142005 20050906 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142005 20050906 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL142005
# /home/fun/data/AL152005
# pick days: ['20050905' '20050909' '20050909']
# sst: (1, 200, 200)
# /home/fun/data/AL152005 20050905 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152005 20050909 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152005 20050909 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL152005
# /home/fun/data/AL162005
# pick days: []
# /home/fun/data/AL172005
# pick days: ['20050917' '20050920' '20050920']
# sst: (1, 200, 200)
# /home/fun/data/AL172005 20050917 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172005 20050920 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172005 20050920 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL172005
# /home/fun/data/AL182005
# pick days: ['20050918' '20050920' '20050920' '20050921' '20050921' '20050922']
# sst: (1, 200, 200)
# /home/fun/data/AL182005 20050921 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL182005 20050921 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL182005 20050922 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL182005
# /home/fun/data/AL192005
# pick days: ['20050930']
# /home/fun/data/AL202005
# pick days: ['20051001']
# /home/fun/data/AL212005
# pick days: ['20051004' '20051004']
# /home/fun/data/AL222005
# pick days: []
# /home/fun/data/AL232005
# pick days: ['20051012' '20051012']
# /home/fun/data/AL242005
# pick days: ['20051009' '20051009']
# /home/fun/data/AL252005
# pick days: ['20051017' '20051018' '20051018' '20051019']
# sst: (1, 200, 200)
# /home/fun/data/AL252005 20051018 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL252005 20051018 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL252005 20051019 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL252005
# /home/fun/data/AL262005
# pick days: ['20051023' '20051023']
# /home/fun/data/AL272005
# pick days: ['20051027' '20051029' '20051029']
# sst: (1, 200, 200)
# /home/fun/data/AL272005 20051027 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL272005 20051029 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL272005 20051029 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL272005
# /home/fun/data/AL282005
# pick days: ['20051120' '20051119']
# /home/fun/data/AL292005
# pick days: ['20051120' '20051124']
# /home/fun/data/AL302005
# pick days: ['20051202' '20051205' '20051208']
# /home/fun/data/AL312005
# pick days: ['20051230' '20060101']
# /home/fun/data/AL012006
# pick days: ['20060610' '20060612']
# /home/fun/data/AL022006
# pick days: ['20060717' '20060717']
# /home/fun/data/AL032006
# pick days: ['20060718' '20060719']
# /home/fun/data/AL042006
# pick days: ['20060801' '20060802']
# /home/fun/data/AL052006
# pick days: ['20060826' '20060823']
# /home/fun/data/AL062006
# pick days: ['20060825' '20060827' '20060827']
# sst: (1, 200, 200)
# /home/fun/data/AL062006 20060825 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL062006 20060827 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL062006 20060827 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL062006
# /home/fun/data/AL082006
# pick days: ['20060911' '20060922' '20060915' '20060915' '20060914']
# sst: (1, 200, 200)
# /home/fun/data/AL082006 20060915 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL082006 20060915 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL082006 20060914 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL082006
# /home/fun/data/AL092006
# pick days: ['20060912' '20060916' '20060917' '20060918' '20060918']
# sst: (1, 200, 200)
# /home/fun/data/AL092006 20060917 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL092006 20060918 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL092006 20060918 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL092006
# /home/fun/data/AL102006
# pick days: ['20060928' '20060930' '20061001']
# sst: (1, 200, 200)
# /home/fun/data/AL102006 20060928 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102006 20060930 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102006 20061001 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL102006
# /home/fun/data/AL012007
# pick days: ['20070507' '20070507' '20070510']
# sst: (1, 200, 200)
# /home/fun/data/AL012007 20070507 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL012007 20070507 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL012007 20070510 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL012007
# /home/fun/data/AL022007
# pick days: ['20070601' '20070601']
# /home/fun/data/AL032007
# pick days: ['20070731' '20070801']
# /home/fun/data/AL042007
# pick days: ['20070814' '20070816' '20070817' '20070817' '20070817' '20070818']
# sst: (1, 200, 200)
# /home/fun/data/AL042007 20070817 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL042007 20070817 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL042007 20070818 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL042007
# /home/fun/data/AL052007
# pick days: ['20070815']
# /home/fun/data/AL062007
# pick days: ['20070831']
# /home/fun/data/AL072007
# pick days: ['20070908']
# /home/fun/data/AL082007
# pick days: ['20070913' '20070914']
# /home/fun/data/AL092007
# pick days: ['20070912' '20070912']
# /home/fun/data/AL102007
# pick days: []
# /home/fun/data/AL112007
# pick days: ['20070923' '20070923']
# /home/fun/data/AL122007
# pick days: ['20070925' '20070926' '20070926']
# sst: (1, 200, 200)
# /home/fun/data/AL122007 20070925 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122007 20070926 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122007 20070926 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL122007
# /home/fun/data/AL132007
# pick days: ['20070926']
# /home/fun/data/AL142007
# pick days: ['20070929' '20070929']
# /home/fun/data/AL152007
# pick days: ['20071016' '20071017']
# /home/fun/data/AL162007
# pick days: ['20071028' '20071104' '20071103']
# sst: (1, 200, 200)
# /home/fun/data/AL162007 20071028 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL162007 20071104 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL162007 20071103 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL162007
# /home/fun/data/AL172007
# pick days: ['20071211' '20071212']
# /home/fun/data/AL012008
# pick days: []
# /home/fun/data/AL022008
# pick days: ['20080703' '20080707' '20080707' '20080707' '20080708']
# sst: (1, 200, 200)
# /home/fun/data/AL022008 20080707 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL022008 20080707 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL022008 20080708 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL022008
# /home/fun/data/AL032008
# pick days: ['20080719' '20080721']
# /home/fun/data/AL042008
# pick days: []
# /home/fun/data/AL052008
# pick days: ['20080803' '20080804']
# /home/fun/data/AL062008
# pick days: ['20080815' '20080818']
# /home/fun/data/AL072008
# pick days: ['20080825' '20080826' '20080830' '20080830' '20080830' '20080830']
# sst: (1, 200, 200)
# /home/fun/data/AL072008 20080830 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072008 20080830 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072008 20080830 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL072008
# /home/fun/data/AL082008
# pick days: ['20080828' '20080902' '20080902']
# sst: (1, 200, 200)
# /home/fun/data/AL082008 20080828 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL082008 20080902 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL082008 20080902 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL082008
# /home/fun/data/AL092008
# pick days: ['20080901' '20080903' '20080908' '20080904' '20080904' '20080906']
# sst: (1, 200, 200)
# /home/fun/data/AL092008 20080904 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL092008 20080904 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL092008 20080906 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL092008
# /home/fun/data/AL102008
# pick days: ['20080902' '20080903']
# /home/fun/data/AL112008
# pick days: ['20080925' '20080927' '20080927']
# sst: (1, 200, 200)
# /home/fun/data/AL112008 20080925 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112008 20080927 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112008 20080927 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL112008
# /home/fun/data/AL122008
# pick days: ['20080927' '20080927']
# /home/fun/data/AL132008
# pick days: ['20081006' '20081006']
# /home/fun/data/AL142008
# pick days: ['20081012' '20081012']
# /home/fun/data/AL152008
# pick days: ['20081013' '20081014' '20081016' '20081016' '20081016']
# sst: (1, 200, 200)
# /home/fun/data/AL152008 20081016 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152008 20081016 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152008 20081016 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL152008
# /home/fun/data/AL162008
# pick days: ['20081014']
# /home/fun/data/AL172008
# pick days: ['20081109' '20081109' '20081107' '20081108' '20081108' '20081109']
# sst: (1, 200, 200)
# /home/fun/data/AL172008 20081108 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172008 20081108 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172008 20081109 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL172008
# /home/fun/data/AL012009
# pick days: ['20090528']
# /home/fun/data/AL022009
# pick days: ['20090812' '20090812']
# /home/fun/data/AL032009
# pick days: ['20090815' '20090817' '20090822' '20090821' '20090819' '20090819']
# sst: (1, 200, 200)
# /home/fun/data/AL032009 20090821 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL032009 20090819 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL032009 20090819 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL032009
# /home/fun/data/AL042009
# pick days: ['20090816']
# /home/fun/data/AL052009
# pick days: ['20090827']
# /home/fun/data/AL062009
# pick days: ['20090901']
# /home/fun/data/AL072009
# pick days: ['20090912' '20090911' '20090909' '20090909' '20090909']
# sst: (1, 200, 200)
# /home/fun/data/AL072009 20090909 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072009 20090909 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072009 20090909 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL072009
# /home/fun/data/AL082009
# pick days: ['20090925']
# /home/fun/data/AL092009
# pick days: ['20090927']
# /home/fun/data/AL102009
# pick days: ['20091006' '20091007']
# /home/fun/data/AL112009
# pick days: ['20091104' '20091104']
# /home/fun/data/AL012010
# pick days: ['20100625']
# /home/fun/data/AL022010
# pick days: ['20100707']
# /home/fun/data/AL032010
# pick days: ['20100722' '20100722']
# /home/fun/data/AL042010
# pick days: ['20100803' '20100805']
# /home/fun/data/AL052010
# pick days: ['20100810']
# /home/fun/data/AL062010
# pick days: ['20100822' '20100830' '20100826' '20100827' '20100827' '20100827']
# sst: (1, 200, 200)
# /home/fun/data/AL062010 20100827 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL062010 20100827 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL062010 20100827 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL062010
# /home/fun/data/AL072010
# pick days: ['20100825' '20100829' '20100903' '20100830' '20100902' '20100902']
# sst: (1, 200, 200)
# /home/fun/data/AL072010 20100830 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072010 20100902 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072010 20100902 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL072010
# /home/fun/data/AL082010
# pick days: ['20100830' '20100901']
# /home/fun/data/AL092010
# pick days: ['20100901' '20100901']
# /home/fun/data/AL102010
# pick days: ['20100906' '20100906']
# /home/fun/data/AL112010
# pick days: ['20100908' '20100911' '20100912' '20100912' '20100915' '20100917']
# sst: (1, 200, 200)
# /home/fun/data/AL112010 20100912 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112010 20100915 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112010 20100917 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL112010
# /home/fun/data/AL122010
# pick days: ['20100921' '20100914' '20100916' '20100915' '20100915' '20100915']
# sst: (1, 200, 200)
# /home/fun/data/AL122010 20100915 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122010 20100915 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122010 20100915 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL122010
# /home/fun/data/AL132010
# pick days: ['20100914' '20100914']
# /home/fun/data/AL142010
# pick days: ['20100926' '20100925' '20100925']
# sst: (1, 200, 200)
# /home/fun/data/AL142010 20100926 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142010 20100925 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142010 20100925 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL142010
# /home/fun/data/AL152010
# pick days: ['20100923' '20100924']
# /home/fun/data/AL162010
# pick days: ['20100928' '20100928']
# /home/fun/data/AL172010
# pick days: ['20101006' '20101008' '20101009']
# sst: (1, 200, 200)
# /home/fun/data/AL172010 20101006 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172010 20101008 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172010 20101009 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL172010
# /home/fun/data/AL182010
# pick days: []
# /home/fun/data/AL192010
# pick days: ['20101021' '20101024' '20101024']
# sst: (1, 200, 200)
# /home/fun/data/AL192010 20101021 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL192010 20101024 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL192010 20101024 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL192010
# /home/fun/data/AL202010
# pick days: ['20101028' '20101029' '20101030']
# sst: (1, 200, 200)
# /home/fun/data/AL202010 20101028 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL202010 20101029 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL202010 20101030 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL202010
# /home/fun/data/AL212010
# pick days: ['20101029' '20101029']
# /home/fun/data/AL012011
# pick days: ['20110628' '20110629']
# /home/fun/data/AL022011
# pick days: ['20110717' '20110718']
# /home/fun/data/AL032011
# pick days: ['20110720' '20110721']
# /home/fun/data/AL042011
# pick days: ['20110727' '20110729']
# /home/fun/data/AL052011
# pick days: ['20110803' '20110804']
# /home/fun/data/AL062011
# pick days: ['20110813' '20110813']
# /home/fun/data/AL072011
# pick days: ['20110814' '20110815']
# /home/fun/data/AL082011
# pick days: ['20110819' '20110819']
# /home/fun/data/AL092011
# pick days: ['20110821']
# /home/fun/data/AL102011
# pick days: ['20110825']
# /home/fun/data/AL112011
# pick days: ['20110827' '20110828']
# /home/fun/data/AL122011
# pick days: ['20110829' '20110911' '20110904' '20110906' '20110906' '20110906']
# sst: (1, 200, 200)
# /home/fun/data/AL122011 20110906 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122011 20110906 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122011 20110906 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL122011
# /home/fun/data/AL202011
# pick days: ['20110901' '20110901']
# /home/fun/data/AL132011
# pick days: ['20110902' '20110903']
# /home/fun/data/AL142011
# pick days: ['20110906' '20110915' '20110916']
# sst: (1, 200, 200)
# /home/fun/data/AL142011 20110906 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142011 20110915 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142011 20110916 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL142011
# /home/fun/data/AL152011
# pick days: ['20110907' '20110908' '20110908']
# sst: (1, 200, 200)
# /home/fun/data/AL152011 20110907 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152011 20110908 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152011 20110908 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL152011
# /home/fun/data/AL162011
# pick days: ['20110928' '20111003' '20110930' '20111002' '20111002' '20111002']
# sst: (1, 200, 200)
# /home/fun/data/AL162011 20111002 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL162011 20111002 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL162011 20111002 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL162011
# /home/fun/data/AL172011
# pick days: ['20110928' '20111006' '20111006']
# sst: (1, 200, 200)
# /home/fun/data/AL172011 20110928 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172011 20111006 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172011 20111006 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL172011
# /home/fun/data/AL182011
# pick days: ['20111023' '20111024' '20111025' '20111025' '20111025']
# sst: (1, 200, 200)
# /home/fun/data/AL182011 20111025 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL182011 20111025 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL182011 20111025 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL182011
# /home/fun/data/AL192011
# pick days: ['20111109']
# /home/fun/data/AL012012
# pick days: ['20120519' '20120520']
# /home/fun/data/AL022012
# pick days: ['20120525' '20120527']
# /home/fun/data/AL032012
# pick days: ['20120617' '20120621' '20120621']
# sst: (1, 200, 200)
# /home/fun/data/AL032012 20120617 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL032012 20120621 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL032012 20120621 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL032012
# /home/fun/data/AL042012
# pick days: ['20120624']
# /home/fun/data/AL052012
# pick days: ['20120802' '20120806']
# /home/fun/data/AL062012
# pick days: ['20120804' '20120805']
# /home/fun/data/AL072012
# pick days: ['20120809']
# /home/fun/data/AL082012
# pick days: ['20120815' '20120818' '20120818' '20120819']
# sst: (1, 200, 200)
# /home/fun/data/AL082012 20120818 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL082012 20120818 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL082012 20120819 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL082012
# /home/fun/data/AL092012
# pick days: ['20120821' '20120827']
# /home/fun/data/AL102012
# pick days: ['20120823' '20120823']
# /home/fun/data/AL112012
# pick days: ['20120828' '20120830' '20120831' '20120831']
# sst: (1, 200, 200)
# /home/fun/data/AL112012 20120830 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112012 20120831 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112012 20120831 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL112012
# /home/fun/data/AL122012
# pick days: ['20120830' '20120905' '20120905']
# sst: (1, 200, 200)
# /home/fun/data/AL122012 20120830 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122012 20120905 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122012 20120905 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL122012
# /home/fun/data/AL132012
# pick days: ['20120904' '20120905' '20120906' '20120906' '20120906']
# sst: (1, 200, 200)
# /home/fun/data/AL132012 20120906 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132012 20120906 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132012 20120906 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL132012
# /home/fun/data/AL142012
# pick days: ['20120911' '20121001' '20120930']
# sst: (1, 200, 200)
# /home/fun/data/AL142012 20120911 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142012 20121001 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142012 20120930 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL142012
# /home/fun/data/AL152012
# pick days: ['20121003' '20121004']
# /home/fun/data/AL162012
# pick days: ['20121011' '20121012']
# /home/fun/data/AL172012
# pick days: ['20121015' '20121016' '20121024']
# sst: (1, 200, 200)
# /home/fun/data/AL172012 20121015 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172012 20121016 - rgb: (200, 200, 44)
# sst: (1, 200, 164)
# /home/fun/data/AL182012
# pick days: ['20121022' '20121024' '20121029' '20121025' '20121025']
# sst: (1, 200, 200)
# /home/fun/data/AL182012 20121029 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL182012 20121025 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL182012 20121025 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL182012
# /home/fun/data/AL192012
# pick days: ['20121022' '20121024']
# /home/fun/data/AL012013
# pick days: ['20130606']
# /home/fun/data/AL022013
# pick days: ['20130616']
# /home/fun/data/AL032013
# pick days: ['20130709']
# /home/fun/data/AL042013
# pick days: ['20130724' '20130725']
# /home/fun/data/AL052013
# pick days: ['20130815' '20130817']
# /home/fun/data/AL062013
# pick days: []
# /home/fun/data/AL072013
# pick days: ['20130910' '20130910']
# /home/fun/data/AL082013
# pick days: []
# /home/fun/data/AL092013
# pick days: ['20130909' '20130911' '20130911']
# sst: (1, 200, 199)
# sst: (1, 200, 200)
# /home/fun/data/AL092013 20130911 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL092013 20130911 - rgb: (200, 200, 44)
# /home/fun/data/AL102013
# pick days: ['20130913' '20130914' '20130915']
# sst: (1, 200, 200)
# /home/fun/data/AL102013 20130913 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102013 20130914 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102013 20130915 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL102013
# /home/fun/data/AL112013
# pick days: ['20130930' '20131001']
# /home/fun/data/AL122013
# pick days: ['20131003']
# /home/fun/data/AL132013
# pick days: ['20131021' '20131022']
# /home/fun/data/AL142013
# pick days: ['20131119']
# /home/fun/data/AL152013
# pick days: ['20131204']
# /home/fun/data/AL012014
# pick days: ['20140701' '20140702' '20140703']
# sst: (1, 200, 200)
# /home/fun/data/AL012014 20140701 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL012014 20140702 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL012014 20140703 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL012014
# /home/fun/data/AL022014
# pick days: ['20140721']
# /home/fun/data/AL032014
# pick days: ['20140729' '20140804' '20140804']
# sst: (1, 200, 200)
# /home/fun/data/AL032014 20140729 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL032014 20140804 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL032014 20140804 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL032014
# /home/fun/data/AL042014
# pick days: ['20140824' '20140830' '20140828']
# sst: (1, 200, 200)
# /home/fun/data/AL042014 20140824 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL042014 20140830 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL042014 20140828 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL042014
# /home/fun/data/AL052014
# pick days: ['20140901' '20140902']
# /home/fun/data/AL062014
# pick days: ['20140920' '20140914' '20140915' '20140916' '20140916']
# sst: (1, 200, 200)
# /home/fun/data/AL062014 20140915 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL062014 20140916 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL062014 20140916 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL062014
# /home/fun/data/AL072014
# pick days: ['20141011']
# /home/fun/data/AL082014
# pick days: ['20141012' '20141012']
# /home/fun/data/AL092014
# pick days: ['20141021']
# /home/fun/data/AL012015
# pick days: ['20150507' '20150509']
# /home/fun/data/AL022015
# pick days: []
# /home/fun/data/AL032015
# pick days: ['20150713' '20150713']
# /home/fun/data/AL042015
# pick days: ['20150818' '20150820' '20150822' '20150821' '20150821']
# sst: (1, 200, 200)
# /home/fun/data/AL042015 20150822 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL042015 20150821 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL042015 20150821 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL042015
# /home/fun/data/AL052015
# pick days: ['20150827']
# /home/fun/data/AL062015
# pick days: ['20150830' '20150901' '20150831']
# sst: (1, 200, 183)
# sst: (1, 200, 200)
# /home/fun/data/AL062015 20150901 - rgb: (200, 200, 44)
# sst: (1, 200, 197)
# /home/fun/data/AL072015
# pick days: ['20150905' '20150906']
# /home/fun/data/AL082015
# pick days: ['20150908' '20150909']
# /home/fun/data/AL092015
# pick days: ['20150917']
# /home/fun/data/AL102015
# pick days: ['20150924' '20150921']
# /home/fun/data/AL112015
# pick days: ['20151010' '20150930' '20150930' '20151002' '20151003' '20151004']
# sst: (1, 200, 200)
# /home/fun/data/AL112015 20151002 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112015 20151003 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112015 20151004 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL112015
# /home/fun/data/AL122015
# pick days: ['20151109' '20151112' '20151111']
# sst: (1, 200, 200)
# /home/fun/data/AL122015 20151109 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122015 20151112 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122015 20151111 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL122015
# /home/fun/data/AL012016
# pick days: ['20160114' '20160114']
# /home/fun/data/AL022016
# pick days: ['20160528' '20160528']
# /home/fun/data/AL032016
# pick days: ['20160605' '20160606']
# /home/fun/data/AL042016
# pick days: ['20160619']
# /home/fun/data/AL052016
# pick days: ['20160803']
# /home/fun/data/AL062016
# pick days: ['20160817' '20160819']
# /home/fun/data/AL072016
# pick days: ['20160822' '20160902' '20160828' '20160829' '20160829']
# sst: (1, 200, 200)
# /home/fun/data/AL072016 20160828 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072016 20160829 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072016 20160829 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL072016
# /home/fun/data/AL082016
# pick days: ['20160828']
# /home/fun/data/AL092016
# pick days: ['20160831' '20160901']
# /home/fun/data/AL102016
# pick days: ['20160916']
# /home/fun/data/AL112016
# pick days: ['20160913' '20160913']
# /home/fun/data/AL122016
# pick days: ['20160915' '20160925']
# /home/fun/data/AL132016
# pick days: ['20160920' '20160921']
# /home/fun/data/AL142016
# pick days: ['20160929' '20160930' '20160930' '20160930' '20161001']
# sst: (1, 200, 200)
# /home/fun/data/AL142016 20160930 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142016 20160930 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142016 20161001 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL142016
# /home/fun/data/AL152016
# pick days: ['20161007' '20161012' '20161013' '20161013' '20161013']
# sst: (1, 200, 200)
# /home/fun/data/AL152016 20161013 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152016 20161013 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL152016 20161013 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL152016
# /home/fun/data/AL162016
# pick days: ['20161121' '20161123' '20161123']
# sst: (1, 200, 200)
# /home/fun/data/AL162016 20161121 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL162016 20161123 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL162016 20161123 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL162016
# /home/fun/data/AL012017
# pick days: ['20170416' '20170418']
# /home/fun/data/AL022017
# pick days: ['20170618' '20170619']
# /home/fun/data/AL032017
# pick days: ['20170621']
# /home/fun/data/AL042017
# pick days: ['20170705']
# /home/fun/data/AL052017
# pick days: ['20170717' '20170717']
# /home/fun/data/AL062017
# pick days: ['20170730']
# /home/fun/data/AL072017
# pick days: ['20170806' '20170807']
# /home/fun/data/AL082017
# pick days: ['20170812' '20170817' '20170816' '20170816']
# sst: (1, 200, 200)
# /home/fun/data/AL082017 20170817 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL082017 20170816 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL082017 20170816 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL082017
# /home/fun/data/AL092017
# pick days: ['20170817']
# /home/fun/data/AL112017
# pick days: ['20170830' '20170831' '20170831' '20170902' '20170904' '20170905']
# sst: (1, 200, 200)
# /home/fun/data/AL112017 20170902 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112017 20170904 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL112017 20170905 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL112017
# /home/fun/data/AL122017
# pick days: ['20170905' '20170906' '20170907' '20170907' '20170908' '20170908']
# /home/fun/data/AL132017
# pick days: ['20170906' '20170906' '20170908']
# /home/fun/data/AL142017
# pick days: ['20170920' '20170924' '20170926' '20170927' '20170927']
# /home/fun/data/AL152017
# pick days: ['20170916' '20170917' '20170918']
# /home/fun/data/AL162017
# pick days: ['20171003']
# /home/fun/data/AL172017
# pick days: ['20171008' '20171011' '20171013' '20171014' '20171014']
# /home/fun/data/AL182017
# pick days: ['20171027']
# /home/fun/data/AL192017
# pick days: ['20171105' '20171108']
# /home/fun/data/AL012018
# pick days: ['20180526' '20180528']
# /home/fun/data/AL022018
# pick days: ['20180710' '20180706' '20180706']
# sst: (1, 200, 200)
# /home/fun/data/AL022018 20180710 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL022018 20180706 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL022018 20180706 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL022018
# /home/fun/data/AL032018
# pick days: ['20180715' '20180710' '20180711' '20180711']
# sst: (1, 200, 200)
# /home/fun/data/AL032018 20180710 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL032018 20180711 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL032018 20180711 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL032018
# /home/fun/data/AL042018
# pick days: ['20180804' '20180809']
# /home/fun/data/AL052018
# pick days: ['20180815' '20180816']
# /home/fun/data/AL062018
# pick days: ['20180901' '20180909' '20180910' '20180910' '20180910' '20180911']
# /home/fun/data/AL072018
# pick days: ['20180903']
# /home/fun/data/AL082018
# pick days: ['20180907' '20180913' '20180910' '20180911']
# /home/fun/data/AL092018
# pick days: ['20180908' '20180909' '20180910']
# /home/fun/data/AL102018
# pick days: ['20180912' '20180916']
# /home/fun/data/AL112018
# pick days: ['20180921']
# /home/fun/data/AL122018
# pick days: ['20180922' '20180926']
# /home/fun/data/AL132018
# pick days: ['20180925' '20181003' '20181012']
# /home/fun/data/AL142018
# pick days: ['20181007' '20181008' '20181008' '20181009' '20181009']
# /home/fun/data/AL152018
# pick days: ['20181009' '20181010']
# /home/fun/data/AL162018
# pick days: ['20181101' '20181030' '20181030']
# /home/fun/data/AL012019
# pick days: ['20190520' '20190521']
# /home/fun/data/AL022019
# pick days: ['20190711' '20190712']
# /home/fun/data/AL032019
# pick days: ['20190722']
# /home/fun/data/AL042019
# pick days: ['20190820' '20190821']
# /home/fun/data/AL052019
# pick days: ['20190824' '20190825']
# /home/fun/data/AL062019
# pick days: ['20190827' '20190827']
# /home/fun/data/AL072019
# pick days: ['20190903' '20190903']
# /home/fun/data/AL082019
# pick days: ['20190903' '20190908']
# /home/fun/data/AL092019
# pick days: ['20190913' '20190915' '20190919' '20190919' '20190918']
# sst: (1, 200, 200)
# /home/fun/data/AL092019 20190919 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL092019 20190919 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL092019 20190918 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL092019
# /home/fun/data/AL102019
# pick days: ['20190918' '20190919' '20190920' '20190920']
# sst: (1, 200, 200)
# /home/fun/data/AL102019 20190919 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102019 20190920 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL102019 20190920 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL102019
# /home/fun/data/AL112019
# pick days: []
# /home/fun/data/AL122019
# pick days: ['20190924' '20190924']
# /home/fun/data/AL132019
# pick days: ['20190923' '20190925' '20191002' '20190929' '20190929' '20190929']
# sst: (1, 200, 200)
# /home/fun/data/AL132019 20190929 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132019 20190929 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL132019 20190929 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL132019
# /home/fun/data/AL142019
# pick days: ['20191010']
# /home/fun/data/AL152019
# pick days: ['20191014']
# /home/fun/data/AL162019
# pick days: ['20191018']
# /home/fun/data/AL172019
# pick days: ['20191026' '20191027']
# /home/fun/data/AL182019
# pick days: ['20191027' '20191027']
# /home/fun/data/AL192019
# pick days: ['20191028' '20191028']
# /home/fun/data/AL202019
# pick days: ['20191123']
# /home/fun/data/AL012020
# pick days: ['20200516' '20200519']
# /home/fun/data/AL022020
# pick days: []
# /home/fun/data/AL032020
# pick days: ['20200602' '20200602']
# /home/fun/data/AL042020
# pick days: ['20200623' '20200623']
# /home/fun/data/AL052020
# pick days: ['20200708' '20200706']
# /home/fun/data/AL062020
# pick days: ['20200709' '20200709']
# /home/fun/data/AL072020
# pick days: ['20200722' '20200723']
# /home/fun/data/AL082020
# pick days: ['20200723' '20200725']
# /home/fun/data/AL092020
# pick days: ['20200801' '20200801']
# /home/fun/data/AL102020
# pick days: ['20200730']
# /home/fun/data/AL112020
# pick days: ['20200813' '20200813']
# /home/fun/data/AL122020
# pick days: ['20200815']
# /home/fun/data/AL132020
# pick days: ['20200820']
# /home/fun/data/AL142020
# pick days: ['20200820' '20200823' '20200823']
# sst: (1, 200, 200)
# /home/fun/data/AL142020 20200820 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142020 20200823 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL142020 20200823 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL142020
# /home/fun/data/AL152020
# pick days: ['20200901' '20200901']
# /home/fun/data/AL162020
# pick days: ['20200901']
# /home/fun/data/AL172020
# pick days: ['20200907' '20200912' '20200913']
# sst: (1, 200, 200)
# /home/fun/data/AL172020 20200907 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172020 20200912 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL172020 20200913 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL172020
# /home/fun/data/AL182020
# pick days: ['20200907' '20200910']
# /home/fun/data/AL192020
# pick days: []
# /home/fun/data/AL202020
# pick days: ['20200912' '20200923' '20200920' '20200917' '20200918' '20200918']
# sst: (1, 200, 200)
# /home/fun/data/AL202020 20200917 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL202020 20200918 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL202020 20200918 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL202020
# /home/fun/data/AL212020
# pick days: ['20200914' '20200914']
# /home/fun/data/AL222020
# pick days: ['20200918' '20200920']
# /home/fun/data/AL232020
# pick days: ['20200917' '20200917']
# /home/fun/data/AL242020
# pick days: ['20200915']
# /home/fun/data/AL252020
# pick days: ['20201002' '20201002']
# /home/fun/data/AL262020
# pick days: ['20201005' '20201005' '20201006' '20201006']
# sst: (1, 200, 200)
# /home/fun/data/AL262020 20201005 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL262020 20201006 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL262020 20201006 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL262020
# /home/fun/data/AL272020
# pick days: ['20201019' '20201025' '20201021' '20201021' '20201021']
# sst: (1, 200, 200)
# /home/fun/data/AL272020 20201021 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL272020 20201021 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL272020 20201021 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL272020
# /home/fun/data/AL282020
# pick days: ['20201024' '20201026' '20201026']
# sst: (1, 200, 200)
# /home/fun/data/AL282020 20201024 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL282020 20201026 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL282020 20201026 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL282020
# /home/fun/data/AL292020
# pick days: ['20201031' '20201102' '20201102' '20201102' '20201103']
# sst: (1, 200, 200)
# /home/fun/data/AL292020 20201102 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL292020 20201102 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL292020 20201103 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL292020
# /home/fun/data/AL302020
# pick days: ['20201109' '20201110']
# /home/fun/data/AL312020
# pick days: ['20201113' '20201115' '20201115' '20201116' '20201116']
# sst: (1, 200, 200)
# /home/fun/data/AL312020 20201115 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL312020 20201116 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL312020 20201116 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL312020
# /home/fun/data/AL012021
# pick days: ['20210520' '20210521']
# /home/fun/data/AL022021
# pick days: ['20210614' '20210615']
# /home/fun/data/AL032021
# pick days: ['20210618' '20210618']
# /home/fun/data/AL042021
# pick days: ['20210627']
# /home/fun/data/AL052021
# pick days: ['20210630' '20210702' '20210702']
# sst: (1, 200, 200)
# /home/fun/data/AL052021 20210630 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL052021 20210702 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL052021 20210702 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL052021
# /home/fun/data/AL062021
# pick days: ['20210813' '20210816']
# /home/fun/data/AL072021
# pick days: ['20210814' '20210818' '20210818']
# sst: (1, 200, 200)
# /home/fun/data/AL072021 20210814 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072021 20210818 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL072021 20210818 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL072021
# /home/fun/data/AL082021
# pick days: ['20210816' '20210821' '20210821']
# sst: (1, 200, 200)
# /home/fun/data/AL082021 20210816 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL082021 20210821 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL082021 20210821 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL082021
# /home/fun/data/AL092021
# pick days: ['20210826' '20210827' '20210828']
# /home/fun/data/AL102021
# pick days: ['20210830' '20210830']
# /home/fun/data/AL112021
# pick days: ['20210829' '20210829']
# /home/fun/data/AL122021
# pick days: ['20210831' '20210902' '20210903' '20210907' '20210904']
# sst: (1, 200, 200)
# /home/fun/data/AL122021 20210903 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122021 20210907 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL122021 20210904 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL122021
# /home/fun/data/AL132021
# pick days: []
# /home/fun/data/AL142021
# pick days: ['20210913']
# /home/fun/data/AL152021
# pick days: ['20210917' '20210920']
# /home/fun/data/AL162021
# pick days: ['20210919' '20210919']
# /home/fun/data/AL172021
# pick days: ['20210919' '20210921']
# /home/fun/data/AL182021
# pick days: ['20210923' '20210924' '20211004' '20210925' '20210927' '20210926']
# sst: (1, 200, 200)
# /home/fun/data/AL182021 20210925 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL182021 20210927 - rgb: (200, 200, 44)
# sst: (1, 200, 200)
# /home/fun/data/AL182021 20210926 - rgb: (200, 200, 44)
# APPENDED /home/fun/data/AL182021
# /home/fun/data/AL192021
# pick days: ['20210924' '20210924']
# /home/fun/data/AL202021
# pick days: ['20211002' '20211001']
# /home/fun/data/AL212021
# pick days: ['20211027']
# (109, 100, 100, 47) (109,)

# %%
highest_cat
ohe_cats = np.zeros((len(highest_cat), int(highest_cat.max())))

for idx, cat in enumerate(highest_cat): 
    ohe_cats[idx, int(cat)-1] = 1
    
# transform highest category (1-5) into one-hot encoded array
# 1 --> [1, 0, 0, 0, 0]
# 5 --> [0, 0, 0, 0, 1]

# allows our neural network to perform multi-class classification with multiple output nodes
# softmax activation function will make the model output positive probabilities for each category

# %%
stages = [stage_1, stage_2, stage_3]

for stage in stages:
    for i in range(stage.shape[0]):
        for j in range(stage.shape[3]):
            scaler = StandardScaler()
            scaler.fit(stage[i, :, :, j])
            stage[i, :, :, j] = scaler.transform(stage[i, :, :, j])
        
print(stage_1.shape, stage_2.shape, stage_3.shape)
# Out:
# (109, 100, 100, 47) (109, 100, 100, 47) (109, 100, 100, 47)

# %%
ohe_cats = ohe_cats.astype("float32")

stage_1 = stage_1.astype("float32")
#stage_1 = np.swapaxes(stage_1, 1, 2)
#stage_1 = np.swapaxes(stage_1, 2, 3)

stage_2 = stage_2.astype("float32")
#stage_2 = np.swapaxes(stage_2, 1, 2)
#stage_2 = np.swapaxes(stage_2, 2, 3)

stage_3 = stage_3.astype("float32")
#stage_3 = np.swapaxes(stage_3, 1, 2)
#stage_3 = np.swapaxes(stage_3, 2, 3)

print(stage_1.shape, stage_2.shape, stage_3.shape)
# Out:
# (109, 100, 100, 47) (109, 100, 100, 47) (109, 100, 100, 47)

# %%
# img
indices = np.arange(0, stage_1.shape[0], 1)
print(len(indices))
print(len(ohe_cats))

index_train, index_test, y_train, y_test = train_test_split(
    indices, ohe_cats, train_size = 0.8, random_state = 3489)

stage_1_train = None
stage_1_test = None

for i in index_train: # get shuffled training datasets
    if stage_1_train is None:
        stage_1_train = stage_1[i:i+1, :, :, :] # i:i+1 to force shape of a 4D tensor, doesn't change index values
        stage_2_train = stage_2[i:i+1, :, :, :]
        stage_3_train = stage_3[i:i+1, :, :, :]
        
    else:
        stage_1_train = np.append(stage_1_train, stage_1[i:i+1, :, :, :], axis = 0)
        stage_2_train = np.append(stage_2_train, stage_2[i:i+1, :, :, :], axis = 0)
        stage_3_train = np.append(stage_3_train, stage_3[i:i+1, :, :, :], axis = 0)

for i in index_test: # get shuffled testing datasets
    if stage_1_test is None:
        stage_1_test = stage_1[i:i+1, :, :, :]
        stage_2_test = stage_2[i:i+1, :, :, :]
        stage_3_test = stage_3[i:i+1, :, :, :]
        
    else:
        stage_1_test = np.append(stage_1_test, stage_1[i:i+1, :, :, :], axis = 0)
        stage_2_test = np.append(stage_2_test, stage_2[i:i+1, :, :, :], axis = 0)
        stage_3_test = np.append(stage_3_test, stage_3[i:i+1, :, :, :], axis = 0)

print(stage_1_train.shape, len(y_train))
print(stage_1_test.shape, len(y_test))
# Out:
# 109
# 109
# (87, 100, 100, 47) 87
# (22, 100, 100, 47) 22

# %%
# stage 1 of hurricane development -- early input data

#channels = 47
#img_size = 100

def create_cnn_model(image_size, channels, num_of_stages):
    
    layers = []  # element of this list is a dictinoary keyed by 'input', 'conv', 'pool'
    flat_list = []
    input_list = []
    
    for i in range(num_of_stages):
        it = {}
        it['input'] = Input(shape = (image_size, image_size, channels),
                      name = 'stage' + str(i+1) + '_input')
        
        it['conv'] = Conv2D(filters = 12, 
               kernel_size = (11, 11), 
               activation = "relu", 
               padding = "same", 
               name = 'stage' + str(i+1) + '_conv')(it['input'])
        
        it['pool'] = AveragePooling2D(pool_size = (2, 2), 
                         strides = 2,
                         name = 'stage' + str(i+1) + '_pool')(it['conv'])
        
        it['batch'] = BatchNormalization(name = 'stage' + str(i+1) +'_batch1')(it['pool'])
        
        it['conv2'] = Conv2D(filters = 12, 
               kernel_size = (11, 11), 
               activation = "relu", 
               padding = "same", 
               name = 'stage' + str(i+1) + '_conv2')(it['batch'])
        
        
        it['pool2'] = AveragePooling2D(pool_size = (2, 2), 
                         strides = 2,
                         name = 'stage' + str(i+1) + '_pool2')(it['conv2'])

        it['batch2'] = BatchNormalization(name = 'stage' + str(i+1) +'_batch2')(it['pool2'])

        it['flat']  = Flatten(name = 'stage' + str(i+1) + '_flat')(it['batch2'])
        
        layers.append(it)
        
        flat_list.append(it['flat'])
        input_list.append(it['input'])
        
    # dense layers -- feature training
    concat = concatenate(flat_list)

    dense1 = Dense(64, activation = "relu", name = 'Fully_Connected_1')(concat)
    dense1dropout = Dropout(0.5, name = 'Dense_Dropout_1')(dense1)

    dense2 = Dense(64, activation = "relu", name = 'Fully_Connected_2')(dense1dropout)
    dense2dropout = Dropout(0.5, name = 'Dense_Dropout_2')(dense2)

    output = Dense(5, activation = "softmax", name = 'Output_Layer')(dense2dropout)

    # create model with two inputs
    model = Model(input_list, output)
    return model

# %%
three_stage_model = create_cnn_model(100, 47, 3)
three_stage_model.summary()
# Out:
# Model: "model_39"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# stage1_input (InputLayer)       [(None, 100, 100, 47 0
# __________________________________________________________________________________________________
# stage2_input (InputLayer)       [(None, 100, 100, 47 0
# __________________________________________________________________________________________________
# stage3_input (InputLayer)       [(None, 100, 100, 47 0
# __________________________________________________________________________________________________
# stage1_conv (Conv2D)            (None, 100, 100, 12) 68256       stage1_input[0][0]
# __________________________________________________________________________________________________
# stage2_conv (Conv2D)            (None, 100, 100, 12) 68256       stage2_input[0][0]
# __________________________________________________________________________________________________
# stage3_conv (Conv2D)            (None, 100, 100, 12) 68256       stage3_input[0][0]
# __________________________________________________________________________________________________
# stage1_pool (AveragePooling2D)  (None, 50, 50, 12)   0           stage1_conv[0][0]
# __________________________________________________________________________________________________
# stage2_pool (AveragePooling2D)  (None, 50, 50, 12)   0           stage2_conv[0][0]
# __________________________________________________________________________________________________
# stage3_pool (AveragePooling2D)  (None, 50, 50, 12)   0           stage3_conv[0][0]
# __________________________________________________________________________________________________
# stage1_batch1 (BatchNormalizati (None, 50, 50, 12)   48          stage1_pool[0][0]
# __________________________________________________________________________________________________
# stage2_batch1 (BatchNormalizati (None, 50, 50, 12)   48          stage2_pool[0][0]
# __________________________________________________________________________________________________
# stage3_batch1 (BatchNormalizati (None, 50, 50, 12)   48          stage3_pool[0][0]
# __________________________________________________________________________________________________
# stage1_conv2 (Conv2D)           (None, 50, 50, 12)   17436       stage1_batch1[0][0]
# __________________________________________________________________________________________________
# stage2_conv2 (Conv2D)           (None, 50, 50, 12)   17436       stage2_batch1[0][0]
# __________________________________________________________________________________________________
# stage3_conv2 (Conv2D)           (None, 50, 50, 12)   17436       stage3_batch1[0][0]
# __________________________________________________________________________________________________
# stage1_pool2 (AveragePooling2D) (None, 25, 25, 12)   0           stage1_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_pool2 (AveragePooling2D) (None, 25, 25, 12)   0           stage2_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_pool2 (AveragePooling2D) (None, 25, 25, 12)   0           stage3_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_batch2 (BatchNormalizati (None, 25, 25, 12)   48          stage1_pool2[0][0]
# __________________________________________________________________________________________________
# stage2_batch2 (BatchNormalizati (None, 25, 25, 12)   48          stage2_pool2[0][0]
# __________________________________________________________________________________________________
# stage3_batch2 (BatchNormalizati (None, 25, 25, 12)   48          stage3_pool2[0][0]
# __________________________________________________________________________________________________
# stage1_flat (Flatten)           (None, 7500)         0           stage1_batch2[0][0]
# __________________________________________________________________________________________________
# stage2_flat (Flatten)           (None, 7500)         0           stage2_batch2[0][0]
# __________________________________________________________________________________________________
# stage3_flat (Flatten)           (None, 7500)         0           stage3_batch2[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 22500)        0           stage1_flat[0][0]
#                                                                  stage2_flat[0][0]
#                                                                  stage3_flat[0][0]
# __________________________________________________________________________________________________
# Fully_Connected_1 (Dense)       (None, 64)           1440064     concatenate_42[0][0]
# __________________________________________________________________________________________________
# Dense_Dropout_1 (Dropout)       (None, 64)           0           Fully_Connected_1[0][0]
# __________________________________________________________________________________________________
# Fully_Connected_2 (Dense)       (None, 64)           4160        Dense_Dropout_1[0][0]
# __________________________________________________________________________________________________
# Dense_Dropout_2 (Dropout)       (None, 64)           0           Fully_Connected_2[0][0]
# __________________________________________________________________________________________________
# Output_Layer (Dense)            (None, 5)            325         Dense_Dropout_2[0][0]
# ==================================================================================================
# Total params: 1,701,913
# Trainable params: 1,701,769
# Non-trainable params: 144
# __________________________________________________________________________________________________

# %%
one_stage_model = create_cnn_model(100, 47, 1)
one_stage_model.summary()
# Out:
# Model: "model_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# stage1_input (InputLayer)    [(None, 100, 100, 47)]    0
# _________________________________________________________________
# stage1_conv (Conv2D)         (None, 100, 100, 12)      68256
# _________________________________________________________________
# stage1_pool (AveragePooling2 (None, 50, 50, 12)        0
# _________________________________________________________________
# stage1_batch1 (BatchNormaliz (None, 50, 50, 12)        48
# _________________________________________________________________
# stage1_conv2 (Conv2D)        (None, 50, 50, 12)        17436
# _________________________________________________________________
# stage1_pool2 (AveragePooling (None, 25, 25, 12)        0
# _________________________________________________________________
# stage1_batch2 (BatchNormaliz (None, 25, 25, 12)        48
# _________________________________________________________________
# stage1_flat (Flatten)        (None, 7500)              0
# _________________________________________________________________
# concatenate_44 (Concatenate) (None, 7500)              0
# _________________________________________________________________
# Fully_Connected_1 (Dense)    (None, 64)                480064
# _________________________________________________________________
# Dense_Dropout_1 (Dropout)    (None, 64)                0
# _________________________________________________________________
# Fully_Connected_2 (Dense)    (None, 64)                4160
# _________________________________________________________________
# Dense_Dropout_2 (Dropout)    (None, 64)                0
# _________________________________________________________________
# Output_Layer (Dense)         (None, 5)                 325
# =================================================================
# Total params: 570,337
# Trainable params: 570,289
# Non-trainable params: 48
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(one_stage_model, to_file='dense_plot.png', show_shapes=True, show_layer_names=True)

# %%
one_stage_model.compile(
    loss = tf.keras.losses.CategoricalCrossentropy(), 
    optimizer = tf.keras.optimizers.Adam(
        learning_rate=0.0005,
    ),
    metrics = tf.keras.losses.CategoricalCrossentropy()
)

history = one_stage_model.fit([
    #stage_1_train, 
    #stage_2_train, 
    stage_3_train
], y_train, 
          batch_size = 5, 
          epochs = 15, 
          validation_data = ([
              #stage_1_test, 
              #stage_2_test, 
              stage_3_test
          ], y_test), 
          )

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], 
           loc='upper left')
# Out:
# Epoch 1/15
# 18/18 [==============================] - 12s 618ms/step - loss: 2.3799 - categorical_crossentropy: 2.4111 - val_loss: 1.6564 - val_categorical_crossentropy: 1.6893
# Epoch 2/15
# 18/18 [==============================] - 11s 608ms/step - loss: 2.4114 - categorical_crossentropy: 2.3613 - val_loss: 1.6008 - val_categorical_crossentropy: 1.6675
# Epoch 3/15
# 18/18 [==============================] - 11s 608ms/step - loss: 2.5258 - categorical_crossentropy: 2.5992 - val_loss: 1.5596 - val_categorical_crossentropy: 1.5846
# Epoch 4/15
# 18/18 [==============================] - 11s 607ms/step - loss: 1.8222 - categorical_crossentropy: 1.8206 - val_loss: 1.5415 - val_categorical_crossentropy: 1.5352
# Epoch 5/15
# 18/18 [==============================] - 11s 608ms/step - loss: 1.7749 - categorical_crossentropy: 1.7576 - val_loss: 1.5296 - val_categorical_crossentropy: 1.5771
# Epoch 6/15
# 18/18 [==============================] - 11s 610ms/step - loss: 1.7985 - categorical_crossentropy: 1.7924 - val_loss: 1.5114 - val_categorical_crossentropy: 1.5292
# Epoch 7/15
# 18/18 [==============================] - 11s 608ms/step - loss: 1.4362 - categorical_crossentropy: 1.4093 - val_loss: 1.4612 - val_categorical_crossentropy: 1.4612
# Epoch 8/15
# 18/18 [==============================] - 11s 609ms/step - loss: 1.6349 - categorical_crossentropy: 1.6425 - val_loss: 1.4750 - val_categorical_crossentropy: 1.4678
# Epoch 9/15
# 18/18 [==============================] - 11s 608ms/step - loss: 1.4619 - categorical_crossentropy: 1.4674 - val_loss: 1.4856 - val_categorical_crossentropy: 1.4821
# Epoch 10/15
# 18/18 [==============================] - 11s 609ms/step - loss: 1.4906 - categorical_crossentropy: 1.4872 - val_loss: 1.4521 - val_categorical_crossentropy: 1.4264
# Epoch 11/15
# 18/18 [==============================] - 11s 607ms/step - loss: 1.5414 - categorical_crossentropy: 1.5474 - val_loss: 1.4836 - val_categorical_crossentropy: 1.4483
# Epoch 12/15
# 18/18 [==============================] - 11s 608ms/step - loss: 1.4189 - categorical_crossentropy: 1.3841 - val_loss: 1.4231 - val_categorical_crossentropy: 1.3869
# Epoch 13/15
# 18/18 [==============================] - 11s 608ms/step - loss: 1.5108 - categorical_crossentropy: 1.5205 - val_loss: 1.3605 - val_categorical_crossentropy: 1.3188
# Epoch 14/15
# 18/18 [==============================] - 11s 609ms/step - loss: 1.3343 - categorical_crossentropy: 1.3304 - val_loss: 1.4314 - val_categorical_crossentropy: 1.3944
# Epoch 15/15
# 18/18 [==============================] - 11s 608ms/step - loss: 1.3833 - categorical_crossentropy: 1.3839 - val_loss: 1.4115 - val_categorical_crossentropy: 1.3602

# %%
def softmaxToCat(y_pred):
    res = []
    for row in y_pred:
        print(y_pred.argmax())

# %%
# Out:
# 3
# 3
# 3
# 3
# 3
# 3

# %%
y_pred = one_stage_model.predict([#stage_1_test, 
                        #stage_2_test, 
                        stage_3_test])
y_pred = y_pred.reshape(y_pred.shape[0])

print(y_test)
print(y_pred)

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(y_test, y_pred, s=30, c='b', marker="s", label='predicted')
ax1.scatter(y_test, y_test, s=30, c='r', marker="o", label='actual')
plt.legend(loc='lower right')
plt.show()
# Out:
# [145.  65. 115. 135.  95. 135.]
# [ 76.03013   17.7485    99.13653  104.92402   58.611446  62.092724]

# %%
y_train_pred = one_stage_model.predict([
    #stage_1_train, 
    #stage_2_train, 
    stage_3_train])
y_train_pred = y_train_pred.reshape(y_train_pred.shape[0])

print(y_train)
print(y_pred)

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(y_train, y_train_pred, s=30, c='b', marker="s", label='predicted')
ax1.scatter(y_train, y_train, s=30, c='r', marker="o", label='actual')
plt.legend(loc='lower right')
plt.show()
# Out:
# [ 65.  90. 125. 145. 120. 155.  75. 110. 125. 145. 100. 125.  75. 100.
#  125. 160. 125. 110. 135. 155. 150.  75. 125.]
# [ 76.03013   17.7485    99.13653  104.92402   58.611446  62.092724]

# %%
import math

percent_error = 0
err_vals = []


for i in range(len(y_test)):
    err = ((y_pred[i] - y_test[i])/y_pred[i])*100
    err_vals = np.append(err_vals, abs(err))
    percent_error = percent_error + abs(err)

mean_error = percent_error/len(y_test)

std_dev_err = err_vals - mean_error
std_dev_err = np.power(std_dev_err, 2)
std_dev_sum = np.sum(std_dev_err)

std_dev = math.sqrt(std_dev_sum/len(err_vals))

print("on average, the model's prediction is", mean_error, "% off of the true max wind speed.")
print("the standard deviation of the error is", std_dev, "knots/hr.")

plt.plot(y_test, err_vals, "ro")
# Out:
# on average, the model's prediction is 96.85155153274536 % off of the true max wind speed.
# the standard deviation of the error is 83.21052525273778 knots/hr.

# %%
'''
stage_array = imerg_array #0
stage_array = np.dstack((stage_array, sst_array)) #1
stage_array = np.dstack((stage_array, rgb_array)) #2-45
stage_array = np.dstack((stage_array, wind_array)) #47
stage_array = np.expand_dims(stage_array, axis = 0)
'''

print(stage_3_test.shape)

#idx = np.where(y_pred=='nan')[0][0]
#print(idx)
test = stage_3_train[3]
print(test.shape)

R_app = test[:, :, 2] # red band
B_app = test[:, :, 10] # blue band
G_app = test[:, :, 14] # green band

#R_app = R_app * 0.001
#B_app = B_app * 0.001
#G_app = G_app * 0.001

color = np.dstack([R_app, G_app, B_app])
print(color.shape)

plt.figure(figsize = (8, 8))
plt.imshow(color)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (24, 200, 200, 47)
# (200, 200, 47)
# (200, 200, 3)

# %%
# outdated data collection methodology -- moved on as of 11/08/2022
def OUTDATED_DATA_COLLECTION():
    highest_wind = np.empty([0])
    imerg_precip = np.empty([1, 10, 200, 200])
    skin_temp = np.empty([1, 4, 200, 200])
    dwt_rgb = np.empty([1, 48, 200, 200])

    all_folders = glob.glob('/home/fun/data/AL*20*')
    all_folders.sort()

    len_fail = 0
    land_fail = 0

    for folder in all_folders:
        imerg_names = folder + '/imerg_precipitation_*.npy'
        sst_names = folder + '/noaa_sst_*.npy'
        rgb_names = folder + '/wavelet_rgb_*.npy'

        if not lenCheck(imerg_names, sst_names, rgb_names):
            print("skipping lenCheck ", folder)
            len_fail += 1
            continue
        if not landCheck(folder, imerg_names, sst_names, rgb_names):
            print("skipping landCheck ", folder)
            land_fail += 1
            continue

        imerg_precip = np.append(imerg_precip, get_imerg(imerg_names), axis = 0) # X data (train class)
        skin_temp = np.append(skin_temp, get_sst(sst_names), axis = 0) # X data (train class)
        dwt_rgb = np.append(dwt_rgb, get_rgb(rgb_names), axis = 0)

        highest_wind = np.append(highest_wind, get_max_wind(folder)) # Y data (target class)

    imerg_precip = imerg_precip[1:]
    skin_temp = skin_temp[1:]
    dwt_rgb = dwt_rgb[1:]

    print(imerg_precip.shape, skin_temp.shape, dwt_rgb.shape, highest_wind.shape)
    print("len_fail: ", len_fail)
    print("land_fail: ", land_fail)
    
    return None # OUTDATED DATA COLLECTION METHOD AS OF 11/08/2022
