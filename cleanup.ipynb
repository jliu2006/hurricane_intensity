# %%
import glob
import os

# %%
folder_list = glob.glob('/home/fun/data/AL*20*/')

for it in folder_list:
    files = glob.glob(it + '10_wavelet*.npy')
    for f in files:
        print ('removing ', f)
        os.remove(f)
# Out:
# removing  /home/fun/data/AL022004/10_wavelet_rgb_20040803.npy
# removing  /home/fun/data/AL022004/10_wavelet_rgb_20040804.npy
# removing  /home/fun/data/AL022004/10_wavelet_rgb_20040805.npy
# removing  /home/fun/data/AL022004/10_wavelet_rgb_20040806.npy
# removing  /home/fun/data/AL022004/10_wavelet_rgb_20040807.npy
# removing  /home/fun/data/AL022004/10_wavelet_rgb_20040808.npy
# removing  /home/fun/data/AL022004/10_wavelet_rgb_20040809.npy
# removing  /home/fun/data/AL022004/10_wavelet_rgb_20040810.npy
# removing  /home/fun/data/AL022004/10_wavelet_rgb_20040811.npy
# removing  /home/fun/data/AL022004/10_wavelet_rgb_20040812.npy
# removing  /home/fun/data/AL042004/10_wavelet_rgb_20040813.npy
# removing  /home/fun/data/AL042004/10_wavelet_rgb_20040814.npy
# removing  /home/fun/data/AL042004/10_wavelet_rgb_20040815.npy
# removing  /home/fun/data/AL042004/10_wavelet_rgb_20040816.npy
# removing  /home/fun/data/AL042004/10_wavelet_rgb_20040817.npy
# ...
